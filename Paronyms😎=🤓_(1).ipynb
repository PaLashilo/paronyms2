# %%
# !pip3 install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.23.0-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.23.0 (from python-Levenshtein)
#   Downloading Levenshtein-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 3.4 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.1.0 (from Levenshtein==0.23.0->python-Levenshtein)
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.23.0 python-Levenshtein-0.23.0 rapidfuzz-3.5.2

# %%
import requests
from bs4 import BeautifulSoup

paronyms = []


# взятие паронимов с открытого ресурса
home_url = 'https://ru-paronym.ru'
ru_alphabet = [chr(i) for i in range(ord('А'), ord('А') + 32)]
no_words = ['Ё', 'Й', 'Щ', 'Ъ', 'Ы', 'Ь']


for letter in ru_alphabet:
    if letter in no_words:
        continue
    url = home_url + '/' + letter
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    arr = soup.find_all('a', href=True)[2:-27]  # Откидываем первые 2 и последние 27 элемента, которые есть на каждой странице
    for elem in arr:
        webpage = home_url + elem['href']
        words = (elem.string).split(' — ')
        paronyms.append(((words[0], words[1]), 1))  # пары слов - паронимы
        paronyms.append(((words[1], words[0]), 1))  # пара в обратном порядке

# %%
# база данных с кортежами с меткой (1) - паронимы
paronyms
# Out:
# [(('абонемент', 'абонент'), 1),
#  (('абонент', 'абонемент'), 1),
#  (('абстрактность', 'абстракция'), 1),
#  (('абстракция', 'абстрактность'), 1),
#  (('авантюрин', 'авантюрист'), 1),
#  (('авантюрист', 'авантюрин'), 1),
#  (('автобиографический', 'автобиографичный'), 1),
#  (('автобиографичный', 'автобиографический'), 1),
#  (('автоматический', 'автоматичный'), 1),
#  (('автоматичный', 'автоматический'), 1),
#  (('автономия', 'автономность'), 1),
#  (('автономность', 'автономия'), 1),
#  (('авторитарный', 'авторитетный'), 1),
#  (('авторитетный', 'авторитарный'), 1),
#  (('адресант', 'адресат'), 1),
#  (('адресат', 'адресант'), 1),
#  (('азарт', 'азартность'), 1),
#  (('азартность', 'азарт'), 1),
#  (('академический', 'академичный'), 1),
#  (('академичный', 'академический'), 1),
#  (('аккордный', 'аккордовый'), 1),
#  (('аккордовый', 'аккордный'), 1),
#  (('акселерат', 'акселератор'), 1),
#  (('акселератор', 'акселерат'), 1),
#  (('активировать', 'активизировать'), 1),
#  (('активизировать', 'активировать'), 1),
#  (('акулий', 'акуловый'), 1),
#  (('акуловый', 'акулий'), 1),
#  (('акционерный', 'акционерский'), 1),
#  (('акционерский', 'акционерный'), 1),
#  (('аллегорический', 'аллегоричный'), 1),
#  (('аллегоричный', 'аллегорический'), 1),
#  (('аллегри', 'аллегро'), 1),
#  (('аллегро', 'аллегри'), 1),
#  (('анархический', 'анархичный'), 1),
#  (('анархичный', 'анархический'), 1),
#  (('английский', 'англиканский'), 1),
#  (('англиканский', 'английский'), 1),
#  (('анекдотический', 'анекдотичный'), 1),
#  (('анекдотичный', 'анекдотический'), 1),
#  (('антагонистический', 'антагонистичный'), 1),
#  (('антагонистичный', 'антагонистический'), 1),
#  (('Антарктика', 'Арктика'), 1),
#  (('Арктика', 'Антарктика'), 1),
#  (('антипатический', 'антипатичный'), 1),
#  (('антипатичный', 'антипатический'), 1),
#  (('антипедагогический', 'антипедагогичный'), 1),
#  (('антипедагогичный', 'антипедагогический'), 1),
#  (('антрацитный', 'антрацитовый'), 1),
#  (('антрацитовый', 'антрацитный'), 1),
#  (('апокрифический', 'апокрифичный'), 1),
#  (('апокрифичный', 'апокрифический'), 1),
#  (('аргонавт', 'астронавт'), 1),
#  (('астронавт', 'аргонавт'), 1),
#  (('аристократический', 'аристократичный'), 1),
#  (('аристократичный', 'аристократический'), 1),
#  (('аритмический', 'аритмичный'), 1),
#  (('аритмичный', 'аритмический'), 1),
#  (('ароматический', 'ароматичный'), 1),
#  (('ароматичный', 'ароматический'), 1),
#  (('артельный', 'артельский'), 1),
#  (('артельский', 'артельный'), 1),
#  (('артистический', 'артистичный'), 1),
#  (('артистичный', 'артистический'), 1),
#  (('архаический', 'архаичный'), 1),
#  (('архаичный', 'архаический'), 1),
#  (('аспирант', 'аспират'), 1),
#  (('аспират', 'аспирант'), 1),
#  (('астматический', 'астматичный'), 1),
#  (('астматичный', 'астматический'), 1),
#  (('атавистический', 'атавистичный'), 1),
#  (('атавистичный', 'атавистический'), 1),
#  (('атака', 'контратака'), 1),
#  (('контратака', 'атака'), 1),
#  (('Атлантида', 'Атлантика'), 1),
#  (('Атлантика', 'Атлантида'), 1),
#  (('бабий', 'бабский'), 1),
#  (('бабский', 'бабий'), 1),
#  (('барский', 'барственный'), 1),
#  (('барственный', 'барский'), 1),
#  (('беглец', 'беженец'), 1),
#  (('беженец', 'беглец'), 1),
#  (('бедный', 'бедственный'), 1),
#  (('бедственный', 'бедный'), 1),
#  (('бедняга', 'бедняк'), 1),
#  (('бедняк', 'бедняга'), 1),
#  (('безвинный', 'невинный'), 1),
#  (('невинный', 'безвинный'), 1),
#  (('безгласный', 'негласный'), 1),
#  (('негласный', 'безгласный'), 1),
#  (('безголосый', 'безголосный'), 1),
#  (('безголосный', 'безголосый'), 1),
#  (('безграмотный', 'неграмотный'), 1),
#  (('неграмотный', 'безграмотный'), 1),
#  (('безграничный', 'неограниченный'), 1),
#  (('неограниченный', 'безграничный'), 1),
#  (('безделица', 'бездельница'), 1),
#  (('бездельница', 'безделица'), 1),
#  (('беззаконие', 'беззаконность'), 1),
#  (('беззаконность', 'беззаконие'), 1),
#  (('безликий', 'безличный'), 1),
#  (('безличный', 'безликий'), 1),
#  (('безответный', 'безответственный'), 1),
#  (('безответственный', 'безответный'), 1),
#  (('безумие', 'безумство'), 1),
#  (('безумство', 'безумие'), 1),
#  (('безыскусный', 'безыскусственный'), 1),
#  (('безыскусственный', 'безыскусный'), 1),
#  (('белеть', 'белить'), 1),
#  (('белить', 'белеть'), 1),
#  (('бережливость', 'бережность'), 1),
#  (('бережность', 'бережливость'), 1),
#  (('бесчувственность', 'бесчувствие'), 1),
#  (('бесчувствие', 'бесчувственность'), 1),
#  (('благодарный', 'благодарственный'), 1),
#  (('благодарственный', 'благодарный'), 1),
#  (('благотворительный', 'благотворный'), 1),
#  (('благотворный', 'благотворительный'), 1),
#  (('благоустроенность', 'благоустройство'), 1),
#  (('благоустройство', 'благоустроенность'), 1),
#  (('ближний', 'близкий'), 1),
#  (('близкий', 'ближний'), 1),
#  (('блистать', 'блестеть'), 1),
#  (('блестеть', 'блистать'), 1),
#  (('блудить', 'блуждать'), 1),
#  (('блуждать', 'блудить'), 1),
#  (('бобёр', 'бобр'), 1),
#  (('бобр', 'бобёр'), 1),
#  (('болезненный', 'болезный'), 1),
#  (('болезный', 'болезненный'), 1),
#  (('болотистый', 'болотный'), 1),
#  (('болотный', 'болотистый'), 1),
#  (('борзой', 'борзый'), 1),
#  (('борзый', 'борзой'), 1),
#  (('бородастый', 'бородатый'), 1),
#  (('бородатый', 'бородастый'), 1),
#  (('братний', 'братский'), 1),
#  (('братский', 'братний'), 1),
#  (('бродяжий', 'бродячий'), 1),
#  (('бродячий', 'бродяжий'), 1),
#  (('будний', 'будничный'), 1),
#  (('будничный', 'будний'), 1),
#  (('булавочный', 'булавчатый'), 1),
#  (('булавчатый', 'булавочный'), 1),
#  (('бунтарь', 'бунтовщик'), 1),
#  (('бунтовщик', 'бунтарь'), 1),
#  (('бур', 'бурав'), 1),
#  (('бурав', 'бур'), 1),
#  (('бывалый', 'бывший'), 1),
#  (('бывший', 'бывалый'), 1),
#  (('в общем', 'вообще'), 1),
#  (('вообще', 'в общем'), 1),
#  (('в одиночестве', 'наедине'), 1),
#  (('наедине', 'в одиночестве'), 1),
#  (('вакансия', 'вакация'), 1),
#  (('вакация', 'вакансия'), 1),
#  (('вакхальный', 'вакханальный'), 1),
#  (('вакханальный', 'вакхальный'), 1),
#  (('ванна', 'ванная'), 1),
#  (('ванная', 'ванна'), 1),
#  (('варение', 'варенье'), 1),
#  (('варенье', 'варение'), 1),
#  (('варенный', 'варёный'), 1),
#  (('варёный', 'варенный'), 1),
#  (('вариант', 'инвариант'), 1),
#  (('инвариант', 'вариант'), 1),
#  (('варкий', 'варочный'), 1),
#  (('варочный', 'варкий'), 1),
#  (('вассальный', 'вассальский'), 1),
#  (('вассальский', 'вассальный'), 1),
#  (('вафельница', 'вафельщица'), 1),
#  (('вафельщица', 'вафельница'), 1),
#  (('вбежать', 'взбежать'), 1),
#  (('взбежать', 'вбежать'), 1),
#  (('вбить', 'взбить'), 1),
#  (('взбить', 'вбить'), 1),
#  (('ввалить', 'взвалить'), 1),
#  (('взвалить', 'ввалить'), 1),
#  (('вдеть', 'вздеть'), 1),
#  (('вздеть', 'вдеть'), 1),
#  (('вдовий', 'вдовый'), 1),
#  (('вдовый', 'вдовий'), 1),
#  (('вдох', 'вздох'), 1),
#  (('вздох', 'вдох'), 1),
#  (('вдохнуть', 'вздохнуть'), 1),
#  (('вздохнуть', 'вдохнуть'), 1),
#  (('вегетативный', 'вегетационный'), 1),
#  (('вегетационный', 'вегетативный'), 1),
#  (('вековой', 'вечный'), 1),
#  (('вечный', 'вековой'), 1),
#  (('великаний', 'великанский'), 1),
#  (('великанский', 'великаний'), 1),
#  (('великий', 'величественный'), 1),
#  (('величественный', 'великий'), 1),
#  (('величие', 'величина'), 1),
#  (('величина', 'величие'), 1),
#  (('венерический', 'венерологический'), 1),
#  (('венерологический', 'венерический'), 1),
#  (('венец', 'венок'), 1),
#  (('венок', 'венец'), 1),
#  (('вера', 'доверие'), 1),
#  (('доверие', 'вера'), 1),
#  (('веселеть', 'веселить'), 1),
#  (('веселить', 'веселеть'), 1),
#  (('весёлый', 'увеселительный'), 1),
#  (('увеселительный', 'весёлый'), 1),
#  (('ветровой', 'ветряной'), 1),
#  (('ветряной', 'ветровой'), 1),
#  (('вечерня', 'вечеря'), 1),
#  (('вечеря', 'вечерня'), 1),
#  (('вешалка', 'вешала'), 1),
#  (('вешала', 'вешалка'), 1),
#  (('взаимопонимание', 'понимание'), 1),
#  (('понимание', 'взаимопонимание'), 1),
#  (('взбитый', 'сбитый'), 1),
#  (('сбитый', 'взбитый'), 1),
#  (('взвесить', 'свесить'), 1),
#  (('свесить', 'взвесить'), 1),
#  (('вздрогнуть', 'дрогнуть'), 1),
#  (('дрогнуть', 'вздрогнуть'), 1),
#  (('взрослеть', 'взрослить'), 1),
#  (('взрослить', 'взрослеть'), 1),
#  (('взрыть', 'врыть'), 1),
#  (('врыть', 'взрыть'), 1),
#  (('взыскательный', 'изысканный'), 1),
#  (('изысканный', 'взыскательный'), 1),
#  (('видение', 'видение'), 1),
#  (('видение', 'видение'), 1),
#  (('виноватый', 'виновный'), 1),
#  (('виновный', 'виноватый'), 1),
#  (('вклад', 'вложение'), 1),
#  (('вложение', 'вклад'), 1),
#  (('владеть', 'обладать'), 1),
#  (('обладать', 'владеть'), 1),
#  (('вначале', 'изначально'), 1),
#  (('изначально', 'вначале'), 1),
#  (('внеклассный', 'внеклассовый'), 1),
#  (('внеклассовый', 'внеклассный'), 1),
#  (('водный', 'водяной'), 1),
#  (('водяной', 'водный'), 1),
#  (('воедино', 'заодно'), 1),
#  (('заодно', 'воедино'), 1),
#  (('военный', 'воинский'), 1),
#  (('воинский', 'военный'), 1),
#  (('вожделенный', 'вожделеющий'), 1),
#  (('вожделеющий', 'вожделенный'), 1),
#  (('возбуждать', 'побуждать'), 1),
#  (('побуждать', 'возбуждать'), 1),
#  (('возлагать', 'налагать'), 1),
#  (('налагать', 'возлагать'), 1),
#  (('возмутительный', 'возмущённый'), 1),
#  (('возмущённый', 'возмутительный'), 1),
#  (('возраст', 'рост'), 1),
#  (('рост', 'возраст'), 1),
#  (('воинственный', 'воинствующий'), 1),
#  (('воинствующий', 'воинственный'), 1),
#  (('войти', 'взойти'), 1),
#  (('взойти', 'войти'), 1),
#  (('волнующий', 'волнительный'), 1),
#  (('волнительный', 'волнующий'), 1),
#  (('волосатый', 'волосистый'), 1),
#  (('волосистый', 'волосатый'), 1),
#  (('вольный', 'произвольный'), 1),
#  (('произвольный', 'вольный'), 1),
#  (('вороний', 'вороновый'), 1),
#  (('вороновый', 'вороний'), 1),
#  (('воскресать', 'воскрешать'), 1),
#  (('воскрешать', 'воскресать'), 1),
#  (('воскресение', 'воскресенье'), 1),
#  (('воскресенье', 'воскресение'), 1),
#  (('воспитательный', 'воспитательский'), 1),
#  (('воспитательский', 'воспитательный'), 1),
#  (('восполнить', 'заполнить'), 1),
#  (('заполнить', 'восполнить'), 1),
#  (('восприемник', 'преемник'), 1),
#  (('преемник', 'восприемник'), 1),
#  (('восход', 'всход'), 1),
#  (('всход', 'восход'), 1),
#  (('впрыгнуть', 'вспрыгнуть'), 1),
#  (('вспрыгнуть', 'впрыгнуть'), 1),
#  (('враждебный', 'вражеский'), 1),
#  (('вражеский', 'враждебный'), 1),
#  (('временник', 'временщик'), 1),
#  (('временщик', 'временник'), 1),
#  (('временной', 'временный'), 1),
#  (('временный', 'временной'), 1),
#  (('вскрытие', 'раскрытие'), 1),
#  (('раскрытие', 'вскрытие'), 1),
#  (('вспоминать', 'поминать'), 1),
#  (('поминать', 'вспоминать'), 1),
#  (('вспыльчивость', 'пылкость'), 1),
#  (('пылкость', 'вспыльчивость'), 1),
#  (('встать', 'стать'), 1),
#  (('стать', 'встать'), 1),
#  (('встряхнуть', 'тряхнуть'), 1),
#  (('тряхнуть', 'встряхнуть'), 1),
#  (('вступить', 'поступить'), 1),
#  (('поступить', 'вступить'), 1),
#  (('всякий', 'всяческий'), 1),
#  (('всяческий', 'всякий'), 1),
#  (('выбор', 'подбор'), 1),
#  (('подбор', 'выбор'), 1),
#  (('выборный', 'выборочный'), 1),
#  (('выборочный', 'выборный'), 1),
#  (('вывёртываться', 'увёртываться'), 1),
#  (('увёртываться', 'вывёртываться'), 1),
#  (('выгода', 'выгодность'), 1),
#  (('выгодность', 'выгода'), 1),
#  (('выдача', 'подача'), 1),
#  (('подача', 'выдача'), 1),
#  (('выдержать', 'сдержать'), 1),
#  (('сдержать', 'выдержать'), 1),
#  (('выжидательный', 'выжидающий'), 1),
#  (('выжидающий', 'выжидательный'), 1),
#  (('вымысел', 'измышление'), 1),
#  (('измышление', 'вымысел'), 1),
#  (('выписать', 'подписать'), 1),
#  (('подписать', 'выписать'), 1),
#  (('выплатить', 'заплатить'), 1),
#  (('заплатить', 'выплатить'), 1),
#  (('вырастить', 'нарастить'), 1),
#  (('нарастить', 'вырастить'), 1),
#  (('высветить', 'высветлить'), 1),
#  (('высветлить', 'высветить'), 1),
#  (('высокий', 'высотный'), 1),
#  (('высотный', 'высокий'), 1),
#  (('высший', 'вышний'), 1),
#  (('вышний', 'высший'), 1),
#  (('выучить', 'изучить'), 1),
#  (('изучить', 'выучить'), 1),
#  (('вязаться', 'связываться'), 1),
#  (('связываться', 'вязаться'), 1),
#  (('гагарий', 'гагаровый'), 1),
#  (('гагаровый', 'гагарий'), 1),
#  (('гадальный', 'гадательный'), 1),
#  (('гадательный', 'гадальный'), 1),
#  (('газовик', 'газовщик'), 1),
#  (('газовщик', 'газовик'), 1),
#  (('гарант', 'гарантия'), 1),
#  (('гарантия', 'гарант'), 1),
#  (('гарантийный', 'гарантированный'), 1),
#  (('гарантированный', 'гарантийный'), 1),
#  (('гармонический', 'гармоничный'), 1),
#  (('гармоничный', 'гармонический'), 1),
#  (('гармония', 'дисгармония'), 1),
#  (('дисгармония', 'гармония'), 1),
#  (('гашенный', 'гашёный'), 1),
#  (('гашёный', 'гашенный'), 1),
#  (('генеральный', 'генеральский'), 1),
#  (('генеральский', 'генеральный'), 1),
#  (('героизм', 'героика'), 1),
#  (('героика', 'героизм'), 1),
#  (('героический', 'геройский'), 1),
#  (('геройский', 'героический'), 1),
#  (('гигиенический', 'гигиеничный'), 1),
#  (('гигиеничный', 'гигиенический'), 1),
#  (('гидрант', 'гидрат'), 1),
#  (('гидрат', 'гидрант'), 1),
#  (('главный', 'заглавный'), 1),
#  (('заглавный', 'главный'), 1),
#  (('гласность', 'огласка'), 1),
#  (('огласка', 'гласность'), 1),
#  (('глинистый', 'глиняный'), 1),
#  (('глиняный', 'глинистый'), 1),
#  (('глубинный', 'глубокий'), 1),
#  (('глубокий', 'глубинный'), 1),
#  (('глупеть', 'глупить'), 1),
#  (('глупить', 'глупеть'), 1),
#  (('гневливый', 'гневный'), 1),
#  (('гневный', 'гневливый'), 1),
#  (('гнездо', 'гнездовье'), 1),
#  (('гнездовье', 'гнездо'), 1),
#  (('гнилой', 'гнилостный'), 1),
#  (('гнилостный', 'гнилой'), 1),
#  (('гнуткий', 'гнутый'), 1),
#  (('гнутый', 'гнуткий'), 1),
#  (('годовалый', 'годовой'), 1),
#  (('годовой', 'годовалый'), 1),
#  (('головашки', 'головешки'), 1),
#  (('головешки', 'головашки'), 1),
#  (('гоночный', 'гончий'), 1),
#  (('гончий', 'гоночный'), 1),
#  (('гончарный', 'гончарский'), 1),
#  (('гончарский', 'гончарный'), 1),
#  (('горделивый', 'гордый'), 1),
#  (('гордый', 'горделивый'), 1),
#  (('гордыня', 'гордость'), 1),
#  (('гордость', 'гордыня'), 1),
#  (('горло', 'горловина'), 1),
#  (('горловина', 'горло'), 1),
#  (('горний', 'горный'), 1),
#  (('горный', 'горний'), 1),
#  (('городничий', 'городовой'), 1),
#  (('городовой', 'городничий'), 1),
#  (('горючий', 'горячий'), 1),
#  (('горячий', 'горючий'), 1),
#  (('господний', 'господский'), 1),
#  (('господский', 'господний'), 1),
#  (('гостиничный', 'гостинный'), 1),
#  (('гостинный', 'гостиничный'), 1),
#  (('гражданский', 'гражданственный'), 1),
#  (('гражданственный', 'гражданский'), 1),
#  (('грамматический', 'грамматичный'), 1),
#  (('грамматичный', 'грамматический'), 1),
#  (('графический', 'графичный'), 1),
#  (('графичный', 'графический'), 1),
#  (('грецкий', 'греческий'), 1),
#  (('греческий', 'грецкий'), 1),
#  (('грибное', 'грибковое'), 1),
#  (('грибковое', 'грибное'), 1),
#  (('грозный', 'грозовой'), 1),
#  (('грозовой', 'грозный'), 1),
#  (('громкий', 'громовой'), 1),
#  (('громовой', 'громкий'), 1),
#  (('грубеть', 'грубить'), 1),
#  (('грубить', 'грубеть'), 1),
#  (('группа', 'группировка'), 1),
#  (('группировка', 'группа'), 1),
#  (('гуманизм', 'гуманность'), 1),
#  (('гуманность', 'гуманизм'), 1),
#  (('гуманный', 'гуманистический'), 1),
#  (('гуманистический', 'гуманный'), 1),
#  (('гусачий', 'гусячий'), 1),
#  (('гусячий', 'гусачий'), 1),
#  (('густеть', 'густить'), 1),
#  (('густить', 'густеть'), 1),
#  (('дар', 'дарственная'), 1),
#  (('дарственная', 'дар'), 1),
#  (('дарёный', 'даровой'), 1),
#  (('даровой', 'дарёный'), 1),
#  (('дармоедный', 'дармоедский'), 1),
#  (('дармоедский', 'дармоедный'), 1),
#  (('двигатель', 'движитель'), 1),
#  (('движитель', 'двигатель'), 1),
#  (('двинуть', 'сдвинуть'), 1),
#  (('сдвинуть', 'двинуть'), 1),
#  (('двоичный', 'двойной'), 1),
#  (('двойной', 'двоичный'), 1),
#  (('двойняшки', 'двояшки'), 1),
#  (('двояшки', 'двойняшки'), 1),
#  (('двойственный', 'двоякий'), 1),
#  (('двоякий', 'двойственный'), 1),
#  (('дворовый', 'придворный'), 1),
#  (('придворный', 'дворовый'), 1),
#  (('двуручный', 'двурушный'), 1),
#  (('двурушный', 'двуручный'), 1),
#  (('дегенерация', 'регенерация'), 1),
#  (('регенерация', 'дегенерация'), 1),
#  (('дедовский', 'дедушкин'), 1),
#  (('дедушкин', 'дедовский'), 1),
#  (('действенный', 'действительный'), 1),
#  (('действительный', 'действенный'), 1),
#  (('действие', 'действо'), 1),
#  (('действо', 'действие'), 1),
#  (('деквалификация', 'дисквалификация'), 1),
#  (('дисквалификация', 'деквалификация'), 1),
#  (('декларативный', 'декларационный'), 1),
#  (('декларационный', 'декларативный'), 1),
#  (('декоративный', 'декорационный'), 1),
#  (('декорационный', 'декоративный'), 1),
#  (('деловитый', 'деловой'), 1),
#  (('деловой', 'деловитый'), 1),
#  (('дельный', 'деляческий'), 1),
#  (('деляческий', 'дельный'), 1),
#  (('дельфиний', 'дельфиновый'), 1),
#  (('дельфиновый', 'дельфиний'), 1),
#  (('демобилизировать', 'мобилизировать'), 1),
#  (('мобилизировать', 'демобилизировать'), 1),
#  (('демократический', 'демократичный'), 1),
#  (('демократичный', 'демократический'), 1),
#  (('демократичность', 'демократия'), 1),
#  (('демократия', 'демократичность'), 1),
#  (('демонстративный', 'демонстрационный'), 1),
#  (('демонстрационный', 'демонстративный'), 1),
#  (('демонтаж', 'монтаж'), 1),
#  (('монтаж', 'демонтаж'), 1),
#  (('депрессия', 'репрессия'), 1),
#  (('репрессия', 'депрессия'), 1),
#  (('держать', 'содержать'), 1),
#  (('содержать', 'держать'), 1),
#  (('дерзать', 'дерзить'), 1),
#  (('дерзить', 'дерзать'), 1),
#  (('деспотизм', 'деспотия'), 1),
#  (('деспотия', 'деспотизм'), 1),
#  (('деспотический', 'деспотичный'), 1),
#  (('деспотичный', 'деспотический'), 1),
#  (('дефектный', 'дефективный'), 1),
#  (('дефективный', 'дефектный'), 1),
#  (('диалект', 'диалектизм'), 1),
#  (('диалектизм', 'диалект'), 1),
#  (('дивизион', 'дивизия'), 1),
#  (('дивизия', 'дивизион'), 1),
#  (('дидактический', 'дидактичный'), 1),
#  (('дидактичный', 'дидактический'), 1),
#  (('диктант', 'диктат'), 1),
#  (('диктат', 'диктант'), 1),
#  (('динамизм', 'динамика'), 1),
#  (('динамика', 'динамизм'), 1),
#  (('динамический', 'динамичный'), 1),
#  (('динамичный', 'динамический'), 1),
#  (('дипломант', 'дипломат'), 1),
#  (('дипломат', 'дипломант'), 1),
#  (('дипломатика', 'дипломатия'), 1),
#  (('дипломатия', 'дипломатика'), 1),
#  (('дипломатический', 'дипломатичный'), 1),
#  (('дипломатичный', 'дипломатический'), 1),
#  (('дифференциальный', 'дифференцированный'), 1),
#  (('дифференцированный', 'дифференциальный'), 1),
#  (('длинный', 'длительный'), 1),
#  (('длительный', 'длинный'), 1),
#  (('днище', 'дно'), 1),
#  (('дно', 'днище'), 1),
#  (('добавить', 'прибавить'), 1),
#  (('прибавить', 'добавить'), 1),
#  (('добавка', 'надбавка'), 1),
#  (('надбавка', 'добавка'), 1),
#  (('добровольный', 'добровольческий'), 1),
#  (('добровольческий', 'добровольный'), 1),
#  (('добрый', 'добротный'), 1),
#  (('добротный', 'добрый'), 1),
#  (('добычливый', 'добычный'), 1),
#  (('добычный', 'добычливый'), 1),
#  (('доверие', 'доверительность'), 1),
#  (('доверительность', 'доверие'), 1),
#  (('доверчивый', 'доверительный'), 1),
#  (('доверительный', 'доверчивый'), 1),
#  (('довольствие', 'довольство'), 1),
#  (('довольство', 'довольствие'), 1),
#  (('догматический', 'догматичный'), 1),
#  (('догматичный', 'догматический'), 1),
#  (('дождевой', 'дождливый'), 1),
#  (('дождливый', 'дождевой'), 1),
#  (('докучливо', 'докучно'), 1),
#  (('докучно', 'докучливо'), 1),
#  (('докучливый', 'докучный'), 1),
#  (('докучный', 'докучливый'), 1),
#  (('доминантный', 'доминантовый'), 1),
#  (('доминантовый', 'доминантный'), 1),
#  (('домовой', 'домовый'), 1),
#  (('домовый', 'домовой'), 1),
#  (('домоправление', 'домоуправление'), 1),
#  (('домоуправление', 'домоправление'), 1),
#  (('допуск', 'допущение'), 1),
#  (('допущение', 'допуск'), 1),
#  (('досадливо', 'досадно'), 1),
#  (('досадно', 'досадливо'), 1),
#  (('досадливый', 'досадный'), 1),
#  (('досадный', 'досадливый'), 1),
#  (('достигать', 'настигать'), 1),
#  (('настигать', 'достигать'), 1),
#  (('достоинство', 'достояние'), 1),
#  (('достояние', 'достоинство'), 1),
#  (('достойно', 'пристойно'), 1),
#  (('пристойно', 'достойно'), 1),
#  (('доходить', 'заходить'), 1),
#  (('заходить', 'доходить'), 1),
#  (('доходный', 'доходчивый'), 1),
#  (('доходчивый', 'доходный'), 1),
#  (('драматический', 'драматичный'), 1),
#  (('драматичный', 'драматический'), 1),
#  (('дружеский', 'дружественный'), 1),
#  (('дружественный', 'дружеский'), 1),
#  (('дудочный', 'дудчатый'), 1),
#  (('дудчатый', 'дудочный'), 1),
#  (('дуреть', 'дурить'), 1),
#  (('дурить', 'дуреть'), 1),
#  (('духовность', 'душевность'), 1),
#  (('душевность', 'духовность'), 1),
#  (('духовный', 'духовой'), 1),
#  (('духовой', 'духовный'), 1),
#  (('дыбом', 'на дыбы'), 1),
#  (('на дыбы', 'дыбом'), 1),
#  (('дымный', 'дымовой'), 1),
#  (('дымовой', 'дымный'), 1),
#  (('единичный', 'одиночный'), 1),
#  (('одиночный', 'единичный'), 1),
#  (('единоверный', 'единоверческий'), 1),
#  (('единоверческий', 'единоверный'), 1),
#  (('единовременный', 'одновременный'), 1),
#  (('одновременный', 'единовременный'), 1),
#  (('единообразие', 'однообразие'), 1),
#  (('однообразие', 'единообразие'), 1),
#  (('единственный', 'единый'), 1),
#  (('единый', 'единственный'), 1),
#  (('естественность', 'естество'), 1),
#  (('естество', 'естественность'), 1),
#  (('жабий', 'жабный'), 1),
#  (('жабный', 'жабий'), 1),
#  (('жавороночий', 'жавороночный'), 1),
#  (('жавороночный', 'жавороночий'), 1),
#  (('жалостливо', 'жалостно'), 1),
#  (('жалостно', 'жалостливо'), 1),
#  (('жалостливый', 'жалостный'), 1),
#  (('жалостный', 'жалостливый'), 1),
#  (('желанный', 'желательный'), 1),
#  (('желательный', 'желанный'), 1),
#  (('желтеть', 'желтить'), 1),
#  (('желтить', 'желтеть'), 1),
#  (('женский', 'женственный'), 1),
#  (('женственный', 'женский'), 1),
#  (('жестокий', 'жёсткий'), 1),
#  (('жёсткий', 'жестокий'), 1),
#  (('живой', 'животный'), 1),
#  (('животный', 'живой'), 1),
#  (('живучий', 'живительный'), 1),
#  (('живительный', 'живучий'), 1),
#  (('жизненный', 'житейский'), 1),
#  (('житейский', 'жизненный'), 1),
#  (('жилой', 'жилищный'), 1),
#  (('жилищный', 'жилой'), 1),
#  (('заблудиться', 'заблуждаться'), 1),
#  (('заблуждаться', 'заблудиться'), 1),
#  (('заботливый', 'заботный'), 1),
#  (('заботный', 'заботливый'), 1),
#  (('завидливый', 'завидный'), 1),
#  (('завидный', 'завидливый'), 1),
#  (('заводной', 'заводской'), 1),
#  (('заводской', 'заводной'), 1),
#  (('завоевательный', 'завоевательский'), 1),
#  (('завоевательский', 'завоевательный'), 1),
#  (('заживать', 'заживлять'), 1),
#  (('заживлять', 'заживать'), 1),
#  (('законодательный', 'законодательский'), 1),
#  (('законодательский', 'законодательный'), 1),
#  (('запасливый', 'запасный'), 1),
#  (('запасный', 'запасливый'), 1),
#  (('заразный', 'заразительный'), 1),
#  (('заразительный', 'заразный'), 1),
#  (('затруднённый', 'затруднительный'), 1),
#  (('затруднительный', 'затруднённый'), 1),
#  (('зачинатель', 'зачинщик'), 1),
#  (('зачинщик', 'зачинатель'), 1),
#  (('защитный', 'защитительный'), 1),
#  (('защитительный', 'защитный'), 1),
#  (('звериный', 'зверский'), 1),
#  (('зверский', 'звериный'), 1),
#  (('звучный', 'звуковой'), 1),
#  (('звуковой', 'звучный'), 1),
#  (('здравица', 'здравница'), 1),
#  (('здравница', 'здравица'), 1),
#  (('зеленеть', 'зеленить'), 1),
#  (('зеленить', 'зеленеть'), 1),
#  (('земляной', 'земной'), 1),
#  (('земной', 'земляной'), 1),
#  (('зернистый', 'зерновой'), 1),
#  (('зерновой', 'зернистый'), 1),
#  (('зимовник', 'зимовщик'), 1),
#  (('зимовщик', 'зимовник'), 1),
#  (('зло', 'злостно'), 1),
#  (('злостно', 'зло'), 1),
#  (('злобный', 'зловещий'), 1),
#  (('зловещий', 'злобный'), 1),
#  (('злой', 'злостный'), 1),
#  (('злостный', 'злой'), 1),
#  (('знамя', 'знамение'), 1),
#  (('знамение', 'знамя'), 1),
#  (('золотеть', 'золотить'), 1),
#  (('золотить', 'золотеть'), 1),
#  (('зрительный', 'зрительский'), 1),
#  (('зрительский', 'зрительный'), 1),
#  (('зубастый', 'зубатый'), 1),
#  (('зубатый', 'зубастый'), 1),
#  (('зубной', 'зубовой'), 1),
#  (('зубовой', 'зубной'), 1),
#  (('зубы', 'зубья'), 1),
#  (('зубья', 'зубы'), 1),
#  (('иголочный', 'игольчатый'), 1),
#  (('игольчатый', 'иголочный'), 1),
#  (('игральный', 'игорный'), 1),
#  (('игорный', 'игральный'), 1),
#  (('игривый', 'игристый'), 1),
#  (('игристый', 'игривый'), 1),
#  (('идеалистистический', 'идеалистичный'), 1),
#  (('идеалистичный', 'идеалистистический'), 1),
#  (('идиотический', 'идиотичный'), 1),
#  (('идиотичный', 'идиотический'), 1),
#  (('иждивенство', 'иждивенчество'), 1),
#  (('иждивенчество', 'иждивенство'), 1),
#  (('избирательный', 'избирательский'), 1),
#  (('избирательский', 'избирательный'), 1),
#  (('изнашиваемость', 'изношенность'), 1),
#  (('изношенность', 'изнашиваемость'), 1),
#  (('изобретательный', 'изобретательский'), 1),
#  (('изобретательский', 'изобретательный'), 1),
#  (('изуверный', 'изверуский'), 1),
#  (('изверуский', 'изуверный'), 1),
#  (('изыскательный', 'изыскательский'), 1),
#  (('изыскательский', 'изыскательный'), 1),
#  (('именной', 'именитый'), 1),
#  (('именитый', 'именной'), 1),
#  (('индейский', 'индийский'), 1),
#  (('индийский', 'индейский'), 1),
#  (('инженерный', 'инженерский'), 1),
#  (('инженерский', 'инженерный'), 1),
#  (('инновация', 'новация'), 1),
#  (('новация', 'инновация'), 1),
#  (('иноверный', 'иноверческий'), 1),
#  (('иноверческий', 'иноверный'), 1),
#  (('инородный', 'инородческий'), 1),
#  (('инородческий', 'инородный'), 1),
#  (('интеллигентный', 'интеллигентский'), 1),
#  (('интеллигентский', 'интеллигентный'), 1),
#  (('интранет', 'интернет'), 1),
#  (('интернет', 'интранет'), 1),
#  (('информативный', 'информационный'), 1),
#  (('информационный', 'информативный'), 1),
#  (('информация', 'информированность'), 1),
#  (('информированность', 'информация'), 1),
#  (('иронический', 'ироничный'), 1),
#  (('ироничный', 'иронический'), 1),
#  (('искательный', 'искательский'), 1),
#  (('искательский', 'искательный'), 1),
#  (('искусно', 'искусственно'), 1),
#  (('искусственно', 'искусно'), 1),
#  (('искусный', 'искусственный'), 1),
#  (('искусственный', 'искусный'), 1),
#  (('исполнительный', 'исполнительский'), 1),
#  (('исполнительский', 'исполнительный'), 1),
#  (('испытательный', 'испытательский'), 1),
#  (('испытательский', 'испытательный'), 1),
#  (('истерический', 'истеричный'), 1),
#  (('истеричный', 'истерический'), 1),
#  (('исток', 'источник'), 1),
#  (('источник', 'исток'), 1),
#  (('исторический', 'историчный'), 1),
#  (('историчный', 'исторический'), 1),
#  (('истребительный', 'истребительский'), 1),
#  (('истребительский', 'истребительный'), 1),
#  (('иструхляветь', 'иструхлявить'), 1),
#  (('иструхлявить', 'иструхляветь'), 1),
#  (('исходный', 'исходящий'), 1),
#  (('исходящий', 'исходный'), 1),
#  (('кабинетный', 'кабинетский'), 1),
#  (('кабинетский', 'кабинетный'), 1),
#  (('каменистый', 'каменный'), 1),
#  (('каменный', 'каменистый'), 1),
#  (('камчатный', 'Камчатский'), 1),
#  (('Камчатский', 'камчатный'), 1),
#  (('каннибал', 'Ганнибал'), 1),
#  (('Ганнибал', 'каннибал'), 1),
#  (('кардинальный', 'кардинальский'), 1),
#  (('кардинальский', 'кардинальный'), 1),
#  (('квадрант', 'квадрат'), 1),
#  (('квадрат', 'квадрант'), 1),
#  (('керосинный', 'керосиновый'), 1),
#  (('керосиновый', 'керосинный'), 1),
#  (('классный', 'классовый'), 1),
#  (('классовый', 'классный'), 1),
#  (('клёв', 'клюв'), 1),
#  (('клюв', 'клёв'), 1),
#  (('клеёночный', 'клеёнчатый'), 1),
#  (('клеёнчатый', 'клеёночный'), 1),
#  (('клеточный', 'клетчатый'), 1),
#  (('клетчатый', 'клеточный'), 1),
#  (('ковкий', 'ковочный'), 1),
#  (('ковочный', 'ковкий'), 1),
#  (('кожаный', 'кожный'), 1),
#  (('кожный', 'кожаный'), 1),
#  (('кокетка', 'кокотка'), 1),
#  (('кокотка', 'кокетка'), 1),
#  (('коллекторный', 'коллекторский'), 1),
#  (('коллекторский', 'коллекторный'), 1),
#  (('командированный', 'командировочный'), 1),
#  (('командировочный', 'командированный'), 1),
#  (('комитент', 'комитет'), 1),
#  (('комитет', 'комитент'), 1),
#  (('комический', 'комичный'), 1),
#  (('комичный', 'комический'), 1),
#  (('комфортный', 'комфортабельный'), 1),
#  (('комфортабельный', 'комфортный'), 1),
#  (('кондукторный', 'кондукторский'), 1),
#  (('кондукторский', 'кондукторный'), 1),
#  (('конный', 'конский'), 1),
#  (('конский', 'конный'), 1),
#  (('конфузливо', 'конфузно'), 1),
#  (('конфузно', 'конфузливо'), 1),
#  (('конфузливый', 'конфузный'), 1),
#  (('конфузный', 'конфузливый'), 1),
#  (('концепция', 'концепт'), 1),
#  (('концепт', 'концепция'), 1),
#  (('конъюнктура', 'конъектура'), 1),
#  (('конъектура', 'конъюнктура'), 1),
#  (('коптеть', 'коптить'), 1),
#  (('коптить', 'коптеть'), 1),
#  (('коренной', 'корневой'), 1),
#  (('корневой', 'коренной'), 1),
#  (('коричневый', 'коричный'), 1),
#  (('коричный', 'коричневый'), 1),
#  (('кормилица', 'кормильщица'), 1),
#  (('кормильщица', 'кормилица'), 1),
#  (('костный', 'костяной'), 1),
#  (('костяной', 'костный'), 1),
#  (('красочный', 'крашеный'), 1),
#  (('крашеный', 'красочный'), 1),
#  (('крестный', 'крёстный'), 1),
#  (('крёстный', 'крестный'), 1),
#  (('критический', 'критичный'), 1),
#  (('критичный', 'критический'), 1),
#  (('крокодилий', 'крокодиловый'), 1),
#  (('крокодиловый', 'крокодилий'), 1),
#  (('крючкотворный', 'крючкотворский'), 1),
#  (('крючкотворский', 'крючкотворный'), 1),
#  (('кулацкий', 'кулачный'), 1),
#  (('кулачный', 'кулацкий'), 1),
#  (('купальник', 'купальщик'), 1),
#  (('купальщик', 'купальник'), 1),
#  (('лавочнический', 'лавочный'), 1),
#  (('лавочный', 'лавочнический'), 1),
#  (('лакированный', 'лакировочный'), 1),
#  (('лакировочный', 'лакированный'), 1),
#  (('легальный', 'легитимный'), 1),
#  (('легитимный', 'легальный'), 1),
#  (('леденеть', 'леденить'), 1),
#  (('леденить', 'леденеть'), 1),
#  (('ледовый', 'ледяной'), 1),
#  (('ледяной', 'ледовый'), 1),
#  (('лесной', 'лесистый'), 1),
#  (('лесистый', 'лесной'), 1),
#  (('летальный', 'летательный'), 1),
#  (('летательный', 'летальный'), 1),
#  (('лирик', 'лирник'), 1),
#  (('лирник', 'лирик'), 1),
#  (('лирический', 'лиричный'), 1),
#  (('лиричный', 'лирический'), 1),
#  (('личный', 'личностный'), 1),
#  (('личностный', 'личный'), 1),
#  (('лобный', 'лобовой'), 1),
#  (('лобовой', 'лобный'), 1),
#  (('ловкий', 'ловчий'), 1),
#  (('ловчий', 'ловкий'), 1),
#  (('логический', 'логичный'), 1),
#  (('логичный', 'логический'), 1),
#  (('ломать', 'ломить'), 1),
#  (('ломить', 'ломать'), 1),
#  (('луковичный', 'луковый'), 1),
#  (('луковый', 'луковичный'), 1),
#  (('малахитный', 'малахитовый'), 1),
#  (('малахитовый', 'малахитный'), 1),
#  (('малопонятливый', 'малопонятный'), 1),
#  (('малопонятный', 'малопонятливый'), 1),
#  (('малоудачливый', 'малоудачный'), 1),
#  (('малоудачный', 'малоудачливый'), 1),
#  (('масленый', 'масличный'), 1),
#  (('масличный', 'масленый'), 1),
#  (('маслянистый', 'масляный'), 1),
#  (('масляный', 'маслянистый'), 1),
#  (('мастистый', 'маститый'), 1),
#  (('маститый', 'мастистый'), 1),
#  (('меланхолический', 'меланхоличный'), 1),
#  (('меланхоличный', 'меланхолический'), 1),
#  (('мелкотравный', 'мелкотравчатый'), 1),
#  (('мелкотравчатый', 'мелкотравный'), 1),
#  (('мелодика', 'мелодия'), 1),
#  (('мелодия', 'мелодика'), 1),
#  (('мелодический', 'мелодичный'), 1),
#  (('мелодичный', 'мелодический'), 1),
#  (('мелодраматический', 'мелодраматичный'), 1),
#  (('мелодраматичный', 'мелодраматический'), 1),
#  (('мельничий', 'мельничный'), 1),
#  (('мельничный', 'мельничий'), 1),
#  (('метафизический', 'метафизичный'), 1),
#  (('метафизичный', 'метафизический'), 1),
#  (('метод', 'методика'), 1),
#  (('методика', 'метод'), 1),
#  (('методистский', 'методический'), 1),
#  (('методический', 'методистский'), 1),
#  (('мечтательный', 'мечтательский'), 1),
#  (('мечтательский', 'мечтательный'), 1),
#  (('микроскопический', 'микроскопичный'), 1),
#  (('микроскопичный', 'микроскопический'), 1),
#  (('мистический', 'мистичный'), 1),
#  (('мистичный', 'мистический'), 1),
#  (('мифический', 'мифичный'), 1),
#  (('мифичный', 'мифический'), 1),
#  (('могильник', 'могильщик'), 1),
#  (('могильщик', 'могильник'), 1),
#  (('могучий', 'могущественный'), 1),
#  (('могущественный', 'могучий'), 1),
#  (('молодеть', 'молодить'), 1),
#  (('молодить', 'молодеть'), 1),
#  (('монистический', 'монистичный'), 1),
#  (('монистичный', 'монистический'), 1),
#  (('мороженый', 'морозный'), 1),
#  (('морозный', 'мороженый'), 1),
#  (('мудреть', 'мудрить'), 1),
#  (('мудрить', 'мудреть'), 1),
#  (('мужицкий', 'мужичий'), 1),
#  (('мужичий', 'мужицкий'), 1),
#  (('мучительный', 'мучительский'), 1),
#  (('мучительский', 'мучительный'), 1),
#  (('наблюдательный', 'наблюдательский'), 1),
#  (('наблюдательский', 'наблюдательный'), 1),
#  (('надувательный', 'надувательский'), 1),
#  (('надувательский', 'надувательный'), 1),
#  (('наёмничий', 'наёмный'), 1),
#  (('наёмный', 'наёмничий'), 1),
#  (('накрапливать', 'накрапывать'), 1),
#  (('накрапывать', 'накрапливать'), 1),
#  (('наличие', 'наличность'), 1),
#  (('наличность', 'наличие'), 1),
#  (('наполнить', 'пополнить'), 1),
#  (('пополнить', 'наполнить'), 1),
#  (('напоминание', 'упоминание'), 1),
#  (('упоминание', 'напоминание'), 1),
#  (('насильно', 'насильственно'), 1),
#  (('насильственно', 'насильно'), 1),
#  (('наследие', 'наследство'), 1),
#  (('наследство', 'наследие'), 1),
#  (('наследный', 'наследственный'), 1),
#  (('наследственный', 'наследный'), 1),
#  (('настоятельный', 'настоятельский'), 1),
#  (('настоятельский', 'настоятельный'), 1),
#  (('натуралистический', 'натуралистичный'), 1),
#  (('натуралистичный', 'натуралистический'), 1),
#  (('нафталан', 'нафталин'), 1),
#  (('нафталин', 'нафталан'), 1),
#  (('начертать', 'начертить'), 1),
#  (('начертить', 'начертать'), 1),
#  (('невежа', 'невежда'), 1),
#  (('невежда', 'невежа'), 1),
#  (('невинный', 'невиновный'), 1),
#  (('невиновный', 'невинный'), 1),
#  (('неврастенический', 'неврастеничный'), 1),
#  (('неврастеничный', 'неврастенический'), 1),
#  (('незаметливый', 'незаметный'), 1),
#  (('незаметный', 'незаметливый'), 1),
#  (('неизмеримый', 'несоизмеримый'), 1),
#  (('несоизмеримый', 'неизмеримый'), 1),
#  (('ненавистнический', 'ненавистный'), 1),
#  (('ненавистный', 'ненавистнический'), 1),
#  (('ненаглядный', 'неоглядный'), 1),
#  (('неоглядный', 'ненаглядный'), 1),
#  (('неорганический', 'неорганичный'), 1),
#  (('неорганичный', 'неорганический'), 1),
#  (('непонятливо', 'непонятно'), 1),
#  (('непонятно', 'непонятливо'), 1),
#  (('непонятливый', 'непонятный'), 1),
#  (('непонятный', 'непонятливый'), 1),
#  (('неприглядный', 'непроглядный'), 1),
#  (('непроглядный', 'неприглядный'), 1),
#  (('неприметливый', 'неприметный'), 1),
#  (('неприметный', 'неприметливый'), 1),
#  (('непроницаемый', 'непроницательный'), 1),
#  (('непроницательный', 'непроницаемый'), 1),
#  (('нестерпимо', 'нетерпимо'), 1),
#  (('нетерпимо', 'нестерпимо'), 1),
#  (('нестерпимый', 'нетерпимый'), 1),
#  (('нетерпимый', 'нестерпимый'), 1),
#  (('неудачливый', 'неудачный'), 1),
#  (('неудачный', 'неудачливый'), 1),
#  (('ниточный', 'нитчатый'), 1),
#  (('нитчатый', 'ниточный'), 1),
#  (('ныне', 'нынче'), 1),
#  (('нынче', 'ныне'), 1),
#  (('обвинительный', 'обвинительский'), 1),
#  (('обвинительский', 'обвинительный'), 1),
#  (('обвязать', 'обязать'), 1),
#  (('обязать', 'обвязать'), 1),
#  (('обделить', 'оделить'), 1),
#  (('оделить', 'обделить'), 1),
#  (('обеднеть', 'обеднить'), 1),
#  (('обеднить', 'обеднеть'), 1),
#  (('обезводеть', 'обезводить'), 1),
#  (('обезводить', 'обезводеть'), 1),
#  (('обезглаветь', 'обезглавить'), 1),
#  (('обезглавить', 'обезглаветь'), 1),
#  (('обезденежеть', 'обезденежить'), 1),
#  (('обезденежить', 'обезденежеть'), 1),
#  (('обездушеть', 'обездушить'), 1),
#  (('обездушить', 'обездушеть'), 1),
#  (('обезземелеть', 'обезземелить'), 1),
#  (('обезземелить', 'обезземелеть'), 1),
#  (('обезлошадеть', 'обезлошадить'), 1),
#  (('обезлошадить', 'обезлошадеть'), 1),
#  (('обезлюдеть', 'обезлюдить'), 1),
#  (('обезлюдить', 'обезлюдеть'), 1),
#  (('обезножеть', 'обезножить'), 1),
#  (('обезножить', 'обезножеть'), 1),
#  (('обезрыбеть', 'обезрыбить'), 1),
#  (('обезрыбить', 'обезрыбеть'), 1),
#  (('обесплодеть', 'обесплодить'), 1),
#  (('обесплодить', 'обесплодеть'), 1),
#  (('обессилеть', 'обессилить'), 1),
#  (('обессилить', 'обессилеть'), 1),
#  (('обжорливый', 'обжорный'), 1),
#  (('обжорный', 'обжорливый'), 1),
#  (('обзолотить', 'озолотить'), 1),
#  (('озолотить', 'обзолотить'), 1),
#  (('обидный', 'обидчивый'), 1),
#  (('обидчивый', 'обидный'), 1),
#  (('обличительный', 'обличительский'), 1),
#  (('обличительский', 'обличительный'), 1),
#  (('обогреть', 'огреть'), 1),
#  (('огреть', 'обогреть'), 1),
#  (('оболванеть', 'оболванить'), 1),
#  (('оболванить', 'оболванеть'), 1),
#  (('оборотливый', 'оборотный'), 1),
#  (('оборотный', 'оборотливый'), 1),
#  (('обоснование', 'основание'), 1),
#  (('основание', 'обоснование'), 1),
#  ...]

# %%
import random


# создание пар слов не паронимов путем перемешивания уже имеющихся слов
def generate_non_paronyms(paronyms, seed = None):
    all_words = set()

    # Создаем множество всех слов из датасета паронимов
    for pair, _ in paronyms:
        all_words.update(pair)

    non_paronyms = []

    if seed:
      random.seed(seed)

    # Случайные пары из множества всех слов
    for _ in range(len(paronyms)):
        word1, word2 = random.choices(list(all_words), k=2)
        if ((word1, word2), 1) not in paronyms:
          non_paronyms.append(((word1, word2), 0))  # Метка 0, так как это непаронимы

    return non_paronyms

non_paronyms = generate_non_paronyms(paronyms, 42)

# %%
dataset = paronyms + non_paronyms
random.shuffle(dataset) # перемешивание датасета на всякий случай
dataset[:10]
# Out:
# [(('собственнический', 'собственный'), 1),
#  (('земной', 'земляной'), 1),
#  (('пластинчатый', 'плавки'), 0),
#  (('токсичный', 'токсический'), 1),
#  (('обязать', 'обвязать'), 1),
#  (('публицистичный', 'движитель'), 0),
#  (('иструхлявить', 'переродниться'), 0),
#  (('кормильщица', 'кормилица'), 1),
#  (('взаимопонимание', 'понимание'), 1),
#  (('дифференцированный', 'тягостно'), 0)]

# %%
import pandas as pd

data = pd.DataFrame(dataset, columns=['word_pair', 'label'])

# %%
from fuzzywuzzy import fuzz
import Levenshtein

def levenshtein_distance(dataset): # вычисление расстояния левенштейна и сходства слов
    distances = []

    for (word1, word2), _ in dataset:
        lev_dist = Levenshtein.distance(word1, word2)
        lev_ratio = fuzz.ratio(word1, word2)
        distances.append((word1, word2, lev_dist, lev_ratio))

    return distances

# %%
lev = levenshtein_distance(dataset)
lev
# Out:
# [('собственнический', 'собственный', 6, 74),
#  ('земной', 'земляной', 2, 86),
#  ('пластинчатый', 'плавки', 8, 44),
#  ('токсичный', 'токсический', 4, 70),
#  ('обязать', 'обвязать', 1, 93),
#  ('публицистичный', 'движитель', 11, 26),
#  ('иструхлявить', 'переродниться', 10, 32),
#  ('кормильщица', 'кормилица', 2, 90),
#  ('взаимопонимание', 'понимание', 6, 75),
#  ('дифференцированный', 'тягостно', 16, 15),
#  ('обезденежить', 'обезденежеть', 1, 92),
#  ('исходный', 'исходящий', 3, 71),
#  ('метафизичный', 'метафизический', 4, 77),
#  ('азартность', 'разместить', 7, 50),
#  ('пьянеть', 'школьный', 8, 27),
#  ('рогастый', 'мелодический', 9, 30),
#  ('остервенеть', 'собирательный', 11, 33),
#  ('автоматичный', 'автоматический', 4, 77),
#  ('кокетка', 'кокотка', 1, 86),
#  ('уклонение', 'отклонение', 2, 84),
#  ('оппортунистический', 'нафталин', 15, 23),
#  ('протрезвить', 'протрезветь', 1, 91),
#  ('прозаический', 'прозаичный', 4, 73),
#  ('ограниченность', 'обесплодеть', 11, 40),
#  ('проследовать', 'последовать', 1, 96),
#  ('фантастический', 'цинический', 6, 67),
#  ('поедим', 'элитарный', 9, 13),
#  ('палатный', 'палаточный', 2, 89),
#  ('усастый', 'усатый', 1, 92),
#  ('штурмовщик', 'грамматичный', 11, 27),
#  ('виноватый', 'виновный', 2, 82),
#  ('тень', 'варочный', 7, 17),
#  ('почтенный', 'почтительный', 4, 76),
#  ('горный', 'доверчивый', 6, 50),
#  ('заводной', 'заводской', 2, 82),
#  ('видение', 'видение', 0, 100),
#  ('накрапывать', 'накрапливать', 2, 87),
#  ('мистический', 'антагонистический', 7, 71),
#  ('стекольный', 'хлеборобный', 6, 48),
#  ('фабрикант', 'фабрикат', 1, 94),
#  ('сатиричный', 'сатирический', 4, 73),
#  ('осиротеть', 'осиротить', 1, 89),
#  ('академический', 'фабрикант', 11, 27),
#  ('сущность', 'преобразовательный', 15, 23),
#  ('малахитовый', 'малахитный', 2, 86),
#  ('информативный', 'сборчатый', 7, 55),
#  ('лавочнический', 'лавочный', 6, 67),
#  ('трубочный', 'трубчатый', 3, 78),
#  ('двойственный', 'двоякий', 8, 42),
#  ('нарастить', 'вступить', 6, 59),
#  ('сатирический', 'вожделенный', 10, 17),
#  ('ближний', 'стеклеть', 8, 13),
#  ('озлеть', 'озлить', 1, 83),
#  ('классный', 'классовый', 2, 82),
#  ('светлить', 'фиеста', 6, 29),
#  ('конный', 'желанный', 4, 57),
#  ('церковничий', 'церковнический', 3, 88),
#  ('гордость', 'гордыня', 4, 53),
#  ('законодательный', 'законодательский', 3, 84),
#  ('поручительный', 'благоустройство', 14, 29),
#  ('пугливый', 'пуганый', 3, 67),
#  ('демократия', 'демократичность', 6, 72),
#  ('рисунчатый', 'рисуночный', 3, 80),
#  ('швейцар', 'изуверный', 7, 38),
#  ('оборотный', 'оборотливый', 3, 80),
#  ('возраст', 'рост', 4, 55),
#  ('солитёр', 'премьерный', 9, 12),
#  ('происки', 'поиски', 1, 92),
#  ('гарант', 'гарантия', 2, 86),
#  ('романтичный', 'произношение', 8, 35),
#  ('доходить', 'заходить', 2, 75),
#  ('хвостистский', 'хвостистый', 3, 82),
#  ('клеёночный', 'клеёнчатый', 3, 80),
#  ('обрывочный', 'обрывчатый', 3, 80),
#  ('демобилизировать', 'мобилизировать', 2, 93),
#  ('начертать', 'начертить', 1, 89),
#  ('фактичный', 'фактический', 4, 70),
#  ('иждивенчество', 'формат', 12, 11),
#  ('логический', 'дерзить', 9, 24),
#  ('жестокий', 'жёсткий', 2, 80),
#  ('памятный', 'памятливый', 3, 78),
#  ('раздеть', 'разодеть', 1, 93),
#  ('корневой', 'пылкость', 8, 25),
#  ('заблудиться', 'холодильщик', 8, 36),
#  ('пометка', 'помета', 1, 92),
#  ('остеклеть', 'геройский', 9, 33),
#  ('целый', 'цельный', 2, 83),
#  ('гармония', 'дисгармония', 3, 84),
#  ('борзой', 'дружественный', 12, 21),
#  ('акулий', 'публицистический', 13, 36),
#  ('фантастический', 'азарт', 11, 32),
#  ('производство', 'жабный', 12, 0),
#  ('прозаический', 'аритмичный', 8, 36),
#  ('рыболовецкий', 'человечий', 6, 57),
#  ('грозовой', 'варение', 8, 13),
#  ('ветровой', 'ветряной', 2, 75),
#  ('воинствующий', 'воинственный', 4, 67),
#  ('ювелирный', 'чувствительный', 9, 52),
#  ('экспонат', 'экспонент', 2, 82),
#  ('поручительный', 'поручительский', 3, 81),
#  ('флегматичный', 'шумный', 8, 44),
#  ('академический', 'академичный', 4, 75),
#  ('совестливо', 'непроницаемый', 12, 17),
#  ('пастушонок', 'пастушок', 2, 89),
#  ('монистический', 'борзой', 11, 21),
#  ('грамматичный', 'грамматический', 4, 77),
#  ('хвостистый', 'хвостистский', 3, 82),
#  ('наедине', 'в одиночестве', 9, 40),
#  ('доминантный', 'доминантовый', 2, 87),
#  ('сетчатый', 'сеточный', 3, 75),
#  ('монтаж', 'безыскусственный', 15, 9),
#  ('вольный', 'пионерный', 5, 50),
#  ('прибавить', 'добавить', 3, 71),
#  ('пакостный', 'пакостливый', 3, 80),
#  ('бунтовщик', 'опытный', 8, 12),
#  ('фантазирование', 'фантазёрство', 7, 62),
#  ('охладить', 'охладеть', 1, 88),
#  ('грибное', 'рыбак', 5, 33),
#  ('скрытый', 'скрытный', 1, 93),
#  ('будничный', 'динамичный', 5, 74),
#  ('раздражительность', 'дефектный', 14, 23),
#  ('обездушить', 'обездушеть', 1, 90),
#  ('стихотворный', 'стихотворческий', 5, 74),
#  ('гордыня', 'гордость', 4, 53),
#  ('лесистый', 'трагический', 8, 42),
#  ('снискать', 'сыскать', 2, 80),
#  ('оцепенить', 'жабный', 8, 13),
#  ('дипломант', 'столовский', 8, 21),
#  ('ограниченность', 'приютский', 12, 26),
#  ('кабинетный', 'оппортунистичный', 11, 38),
#  ('леденеть', 'леденить', 1, 88),
#  ('информативный', 'информационный', 3, 81),
#  ('беззаконие', 'беззаконность', 5, 70),
#  ('масличный', 'масленый', 2, 82),
#  ('заботный', 'коптеть', 7, 27),
#  ('отряхнуть', 'стряхнуть', 1, 89),
#  ('отходный', 'старинный', 5, 47),
#  ('ироничный', 'иронический', 4, 70),
#  ('вбить', 'произвольный', 10, 24),
#  ('человеческий', 'методика', 9, 30),
#  ('вздохнуть', 'ловчий', 8, 13),
#  ('оформительный', 'оформительский', 3, 81),
#  ('монистичный', 'хлебопашеский', 12, 33),
#  ('доверчивый', 'бедный', 7, 38),
#  ('болотный', 'болотистый', 3, 78),
#  ('горный', 'шлифовальщик', 11, 11),
#  ('безыскусный', 'сладостный', 8, 48),
#  ('ординарческий', 'сломленный', 11, 26),
#  ('авантюрист', 'корневой', 9, 11),
#  ('авантюрист', 'авантюрин', 2, 84),
#  ('понятный', 'понятливый', 3, 78),
#  ('хозяйственный', 'хозяйский', 6, 64),
#  ('статический', 'статичный', 4, 70),
#  ('бородастый', 'бородатый', 1, 95),
#  ('малопонятливый', 'малопонятный', 3, 85),
#  ('рогатый', 'рогастый', 1, 93),
#  ('распутица', 'распутница', 1, 95),
#  ('волосатый', 'ремесленнический', 14, 24),
#  ('бедственный', 'бедный', 5, 71),
#  ('отплатить', 'оплатить', 1, 94),
#  ('типический', 'ненаглядный', 10, 19),
#  ('озолотеть', 'факт', 8, 15),
#  ('газовик', 'газовщик', 1, 93),
#  ('расточительский', 'расточительный', 3, 83),
#  ('зачинщик', 'гидрат', 7, 14),
#  ('водяной', 'болезный', 5, 40),
#  ('именитый', 'именной', 3, 67),
#  ('садовнический', 'садовничий', 3, 87),
#  ('экзерциции', 'экзерсисы', 4, 63),
#  ('безответный', 'потребительный', 9, 56),
#  ('горный', 'систематический', 14, 10),
#  ('гидрат', 'гидрант', 1, 92),
#  ('всякий', 'поэтический', 8, 47),
#  ('малоудачливый', 'цветовой', 11, 29),
#  ('дипломатический', 'камчатный', 12, 33),
#  ('бывалый', 'проповедничий', 11, 20),
#  ('идиотичный', 'идиотический', 4, 73),
#  ('Ганнибал', 'каннибал', 1, 88),
#  ('черви', 'червы', 1, 80),
#  ('обсудить', 'осудить', 1, 93),
#  ('иноверный', 'духовность', 8, 32),
#  ('грамматичный', 'конский', 10, 21),
#  ('чеканочный', 'чеканный', 2, 89),
#  ('подрядческий', 'приютский', 6, 57),
#  ('начертить', 'токсичный', 9, 22),
#  ('ябедный', 'ябедливый', 3, 75),
#  ('бродячий', 'бродяжий', 1, 88),
#  ('дельфиний', 'личностный', 8, 42),
#  ('англиканский', 'угодливый', 10, 38),
#  ('весёлый', 'увеселительный', 8, 57),
#  ('ремесленнический', 'ремесленный', 6, 74),
#  ('удвоенный', 'эфирный', 6, 38),
#  ('обсуждение', 'осуждение', 1, 95),
#  ('памятливый', 'дымовой', 7, 35),
#  ('пастушеский', 'господский', 6, 48),
#  ('потребительный', 'малопонятный', 11, 46),
#  ('хлеборобский', 'сдвоенный', 10, 19),
#  ('седельчатый', 'седельный', 3, 80),
#  ('обрывчатый', 'артистический', 11, 26),
#  ('иждивенчество', 'иждивенство', 2, 92),
#  ('ироничный', 'доверительность', 13, 25),
#  ('мучительный', 'мучительский', 3, 78),
#  ('гагаровый', 'гагарий', 3, 75),
#  ('действие', 'простецкий', 7, 33),
#  ('продуктивный', 'жавороночий', 11, 35),
#  ('сытый', 'поэтичный', 6, 43),
#  ('головешки', 'головашки', 1, 89),
#  ('жизненный', 'житейский', 6, 44),
#  ('методистский', 'методический', 2, 83),
#  ('звуковой', 'непроглядный', 10, 20),
#  ('антипедагогичный', 'антипедагогический', 4, 82),
#  ('глубинный', 'глубокий', 4, 71),
#  ('единый', 'комфортабельный', 11, 38),
#  ('юмористка', 'юмореска', 2, 82),
#  ('керосиновый', 'керосинный', 2, 86),
#  ('темь', 'тень', 1, 75),
#  ('оградить', 'огородить', 2, 82),
#  ('обездушеть', 'обездушить', 1, 90),
#  ('добавка', 'надбавка', 3, 80),
#  ('шершавить', 'шершаветь', 1, 89),
#  ('длинный', 'длительный', 4, 71),
#  ('вакансия', 'пьянить', 7, 27),
#  ('гадальный', 'конфузливый', 8, 30),
#  ('регенерация', 'дегенерация', 1, 91),
#  ('хлеборобный', 'четырёхрукий', 10, 26),
#  ('вдовый', 'вдовий', 1, 83),
#  ('сладко', 'предоставление', 12, 20),
#  ('враждебный', 'неграмотный', 7, 48),
#  ('озолотеть', 'озолотить', 1, 89),
#  ('героический', 'геройский', 3, 80),
#  ('длинный', 'эффектный', 6, 38),
#  ('поручительский', 'ломать', 11, 30),
#  ('порумянить', 'порумянеть', 1, 90),
#  ('гордый', 'информация', 8, 25),
#  ('удачливо', 'обязать', 8, 13),
#  ('токсичный', 'шумный', 6, 40),
#  ('наблюдательский', 'надувательский', 4, 83),
#  ('нетерпимый', 'варкий', 7, 38),
#  ('отпечатки', 'опечатки', 1, 94),
#  ('малоудачливый', 'малоудачный', 3, 83),
#  ('иголочный', 'термический', 9, 30),
#  ('рыболовецкий', 'рыболовный', 4, 73),
#  ('метафизичный', 'гарантия', 10, 20),
#  ('неограниченный', 'безграничный', 4, 77),
#  ('старинный', 'старый', 3, 80),
#  ('удачный', 'удачливый', 3, 75),
#  ('пансионер', 'мечтательный', 10, 19),
#  ('дармоедный', 'дармоедский', 3, 76),
#  ('популистский', 'популярный', 6, 55),
#  ('червить', 'здравница', 6, 38),
#  ('веселеть', 'веселить', 1, 88),
#  ('стяжательный', 'стяжательский', 3, 80),
#  ('заводской', 'рожать', 8, 13),
#  ('огородить', 'оградить', 2, 82),
#  ('теоретический', 'теоретичный', 4, 75),
#  ('темнить', 'сопротивляемость', 11, 43),
#  ('мелодичный', 'мелодический', 4, 73),
#  ('экзерсисы', 'заодно', 8, 13),
#  ('холодильщик', 'холодильник', 1, 91),
#  ('выписать', 'охладеть', 6, 38),
#  ('осветлитель', 'осветитель', 1, 95),
#  ('пластинчатый', 'сытый', 8, 47),
#  ('конский', 'возмутительный', 11, 29),
#  ('оппортунистический', 'оппортунистичный', 4, 82),
#  ('тактичный', 'тактический', 4, 70),
#  ('довольствие', 'довольство', 2, 86),
#  ('группа', 'группировка', 5, 71),
#  ('главный', 'сметливый', 6, 50),
#  ('надувательский', 'надувательный', 3, 81),
#  ('дудочный', 'отречение', 7, 35),
#  ('отграничить', 'формант', 8, 56),
#  ('дарственная', 'дар', 8, 43),
#  ('венок', 'выписать', 7, 15),
#  ('раскрытие', 'догматичный', 10, 30),
#  ('подживлять', 'сочинительный', 10, 35),
#  ('обезножить', 'обезножеть', 1, 90),
#  ('сломленный', 'сломанный', 2, 84),
#  ('жавороночий', 'терпеливость', 11, 17),
#  ('командированный', 'командировочный', 2, 87),
#  ('досадный', 'вариант', 7, 27),
#  ('клеточный', 'клетчатый', 3, 78),
#  ('мистичный', 'вассальный', 6, 42),
#  ('придворный', 'дворовый', 5, 67),
#  ('четырёхрукий', 'парламентёрский', 11, 52),
#  ('отречение', 'отрешение', 1, 89),
#  ('беженец', 'пометка', 6, 14),
#  ('догматический', 'информированность', 15, 27),
#  ('личный', 'личностный', 4, 75),
#  ('вера', 'доверие', 4, 55),
#  ('монистичный', 'монистический', 4, 75),
#  ('деспотичный', 'каменистый', 8, 48),
#  ('мужицкий', 'мужичий', 2, 80),
#  ('безделица', 'бездельница', 2, 90),
#  ('пополнить', 'наполнить', 2, 78),
#  ('душевность', 'акционерский', 10, 18),
#  ('вывёртываться', 'увёртываться', 2, 88),
#  ('бывший', 'бывалый', 3, 62),
#  ('гнездовье', 'гнездо', 3, 80),
#  ('циничный', 'токсичный', 4, 59),
#  ('заодно', 'отрешение', 8, 27),
#  ('шутливый', 'шуточный', 3, 62),
#  ('глиняный', 'производительность', 16, 15),
#  ('испытательный', 'испытательский', 3, 81),
#  ('ванная', 'коллекторный', 11, 11),
#  ('деквалификация', 'догматичный', 11, 24),
#  ('симпатический', 'разместиться', 10, 32),
#  ('сапожный', 'сапожничий', 3, 78),
#  ('отписка', 'описка', 1, 92),
#  ('академичный', 'изобретательный', 11, 38),
#  ('отклик', 'обличительный', 10, 32),
#  ('рисковый', 'рисковой', 1, 88),
#  ('доверие', 'доверительность', 8, 64),
#  ('гигиенический', 'информация', 11, 26),
#  ('добровольный', 'добровольческий', 5, 74),
#  ('вариант', 'инвариант', 2, 88),
#  ('докучливый', 'докучный', 3, 78),
#  ('взбежать', 'пастушок', 8, 25),
#  ('техничный', 'технический', 4, 70),
#  ('доходчивый', 'доходный', 3, 78),
#  ('патриотичный', 'патриотический', 4, 77),
#  ('ломать', 'ломить', 1, 83),
#  ('породить', 'породнить', 1, 94),
#  ('фён', 'системный', 8, 17),
#  ('горячий', 'фланелевый', 9, 12),
#  ('безумие', 'безумство', 4, 62),
#  ('клёв', 'крокодиловый', 9, 38),
#  ('совестно', 'увеселительный', 10, 45),
#  ('осудить', 'обсудить', 1, 93),
#  ('тема', 'тематика', 4, 67),
#  ('собирательный', 'собирательский', 3, 81),
#  ('гадальный', 'гадательный', 2, 90),
#  ('здравица', 'вдохнуть', 7, 12),
#  ('строительский', 'графичный', 11, 27),
#  ('крестный', 'крёстный', 1, 88),
#  ('газовик', 'непроглядный', 11, 11),
#  ('нитчатый', 'ниточный', 3, 75),
#  ('действо', 'действие', 2, 80),
#  ('охладеть', 'безликий', 8, 12),
#  ('естественность', 'ковочный', 12, 18),
#  ('гнилой', 'шутливый', 6, 29),
#  ('гашёный', 'памятливый', 7, 35),
#  ('запасливый', 'стрелчатый', 8, 40),
#  ('подписать', 'выписать', 3, 71),
#  ('громовой', 'заглавный', 7, 35),
#  ('клюв', 'изобретательский', 15, 10),
#  ('неограниченный', 'дарёный', 10, 38),
#  ('дружественный', 'дружеский', 6, 64),
#  ('темнеть', 'орлиный', 7, 14),
#  ('пластинчатый', 'толстить', 8, 50),
#  ('сыскать', 'снискать', 2, 80),
#  ('остеклеть', 'автобиографический', 16, 22),
#  ('педагогичный', 'педагогический', 4, 77),
#  ('гагарий', 'пуганый', 4, 43),
#  ('вафельница', 'вафельщица', 1, 90),
#  ('зрительный', 'докучно', 9, 12),
#  ('дидактичный', 'оппортунистический', 14, 34),
#  ('экранировать', 'предоставление', 13, 31),
#  ('яловый', 'яловочный', 3, 80),
#  ('предоставление', 'мечтательский', 11, 37),
#  ('керосиновый', 'волнующий', 9, 30),
#  ('полированный', 'полировочный', 2, 83),
#  ('этичный', 'этический', 4, 62),
#  ('холодить', 'выгода', 6, 29),
#  ('молодить', 'разместиться', 9, 40),
#  ('хлебопашенный', 'свесить', 12, 10),
#  ('живучий', 'живительный', 7, 56),
#  ('цветастый', 'заразительный', 10, 36),
#  ('атавистический', 'атавистичный', 4, 77),
#  ('перетерпеть', 'претерпеть', 1, 95),
#  ('грозный', 'стрелец', 7, 14),
#  ('обвинительский', 'обвинительный', 3, 81),
#  ('сломанный', 'единственный', 8, 48),
#  ('сеточный', 'коренной', 6, 38),
#  ('желтеть', 'отдельный', 7, 38),
#  ('разборчивый', 'ограничение', 10, 36),
#  ('дымный', 'дымовой', 3, 62),
#  ('вакхальный', 'вакханальный', 2, 91),
#  ('ребристый', 'ребрастый', 1, 89),
#  ('великанский', 'цепенить', 9, 32),
#  ('квадрант', 'обезлюдеть', 9, 22),
#  ('воскресать', 'артельский', 9, 30),
#  ('обессилить', 'демонстративный', 13, 24),
#  ('дедовский', 'праздничный', 9, 30),
#  ('оформительный', 'вражеский', 10, 27),
#  ('добычливый', 'добычный', 3, 78),
#  ('расчётный', 'пастушок', 7, 35),
#  ('наличность', 'различие', 7, 44),
#  ('гражданственный', 'наследный', 9, 50),
#  ('огреть', 'обогреть', 2, 86),
#  ('днище', 'дно', 3, 50),
#  ('на дыбы', 'дыбом', 5, 50),
#  ('отходный', 'собственный', 6, 53),
#  ('благодарственный', 'стрелок', 13, 26),
#  ('оформительный', 'фён', 11, 25),
#  ('сетчатый', 'заблуждаться', 10, 20),
#  ('домоправление', 'эффектность', 13, 17),
#  ('цветы', 'венец', 4, 40),
#  ('элитарный', 'элитный', 2, 88),
#  ('заодно', 'рожать', 6, 17),
#  ('анекдотический', 'доверие', 10, 38),
#  ('примотать', 'приметать', 1, 89),
#  ('представиться', 'преставиться', 1, 96),
#  ('заразный', 'сапожный', 4, 50),
#  ('производство', 'бедняк', 11, 11),
#  ('летательный', 'политический', 9, 35),
#  ('драматичный', 'осиротить', 9, 30),
#  ('подвижнический', 'подвижный', 6, 70),
#  ('потребительский', 'потребительный', 3, 83),
#  ('единоверческий', 'вложение', 11, 27),
#  ('налагать', 'раскольничий', 10, 30),
#  ('домовой', 'домовый', 1, 86),
#  ('полюс', 'конфузливый', 9, 25),
#  ('приветственный', 'гласность', 12, 17),
#  ('прожигательский', 'прожигательный', 3, 83),
#  ('приветный', 'пуганый', 5, 50),
#  ('золотеть', 'тень', 5, 50),
#  ('хлебопашенный', 'хлебопашеский', 3, 77),
#  ('приветный', 'приветственный', 5, 78),
#  ('варочный', 'варкий', 4, 57),
#  ('черепаший', 'черепаховый', 4, 70),
#  ('юродливый', 'юродивый', 1, 94),
#  ('отборник', 'сбитый', 7, 29),
#  ('вегетационный', 'автономия', 11, 36),
#  ('синеть', 'гуманизм', 7, 14),
#  ('дыбом', 'на дыбы', 5, 50),
#  ('спасательный', 'наследный', 6, 57),
#  ('внеклассный', 'внеклассовый', 2, 87),
#  ('собирательский', 'приютский', 8, 52),
#  ('акселерат', 'демобилизировать', 12, 40),
#  ('оглупить', 'оглупеть', 1, 88),
#  ('возмутительный', 'возмущённый', 6, 64),
#  ('настоятельный', 'настоятельский', 3, 81),
#  ('представить', 'белить', 7, 47),
#  ('аллегри', 'избирательный', 11, 20),
#  ('псарский', 'скрытный', 6, 38),
#  ('крючкотворный', 'крючкотворский', 3, 81),
#  ('мелкотравный', 'мелкотравчатый', 3, 85),
#  ('гордыня', 'лирик', 6, 17),
#  ('отговорка', 'двойной', 8, 25),
#  ('высший', 'вышний', 2, 83),
#  ('грецкий', 'греческий', 3, 75),
#  ('циклический', 'испытательский', 9, 48),
#  ('обстоятельный', 'обстоятельственный', 5, 84),
#  ('подача', 'выдача', 2, 67),
#  ('вообще', 'в общем', 2, 77),
#  ('ниточный', 'нитчатый', 3, 75),
#  ('отклонение', 'в общем', 9, 24),
#  ('приютный', 'приютский', 3, 71),
#  ('напоминание', 'ярый', 11, 0),
#  ('каменистый', 'каменный', 3, 78),
#  ('демократический', 'демократичный', 4, 79),
#  ('клетчатый', 'газовик', 9, 12),
#  ('животный', 'живой', 3, 77),
#  ('диктат', 'диктант', 1, 92),
#  ('горючий', 'увёртываться', 11, 11),
#  ('явный', 'великаний', 7, 43),
#  ('дипломат', 'Атлантида', 9, 35),
#  ('грозный', 'графичный', 4, 62),
#  ('педагогический', 'педагогичный', 4, 77),
#  ('психологичный', 'психологический', 4, 79),
#  ('заблудиться', 'заблуждаться', 2, 87),
#  ('мистический', 'мистичный', 4, 70),
#  ('авторитетный', 'штатный', 7, 53),
#  ('ребрастый', 'ребристый', 1, 89),
#  ('скотский', 'изначально', 10, 11),
#  ('дельфиний', 'разночинский', 8, 38),
#  ('реалистический', 'реалистичный', 4, 77),
#  ('бедняга', 'скотный', 7, 14),
#  ('наедине', 'угодно', 5, 31),
#  ('домовый', 'ванная', 7, 15),
#  ('великанский', 'великаний', 2, 90),
#  ('генеральский', 'заводной', 10, 20),
#  ('духовный', 'духовой', 2, 80),
#  ('владеть', 'обладать', 3, 67),
#  ('элегичный', 'элегический', 4, 70),
#  ('шелковый', 'обсуждение', 10, 11),
#  ('полюс', 'псарный', 6, 33),
#  ('парламентёрский', 'золотить', 13, 26),
#  ('царский', 'царственный', 6, 56),
#  ('чубатый', 'чубастый', 1, 93),
#  ('заживать', 'заживлять', 2, 82),
#  ('российский', 'черстветь', 9, 21),
#  ('советник', 'советчик', 1, 88),
#  ('заразный', 'заразительный', 5, 76),
#  ('сочинительный', 'сочинительский', 3, 81),
#  ('понятливый', 'понятный', 3, 78),
#  ('фееричный', 'раскрытие', 9, 22),
#  ('обвинительный', 'обвинительский', 3, 81),
#  ('цепенить', 'городничий', 8, 22),
#  ('дудчатый', 'дудочный', 3, 75),
#  ('талан', 'вороний', 6, 17),
#  ('оцепенить', 'переродиться', 8, 48),
#  ('апокрифический', 'апокрифичный', 4, 77),
#  ('обрывчатый', 'дипломатичный', 9, 43),
#  ('хозяйский', 'представить', 10, 20),
#  ('начертить', 'начертать', 1, 89),
#  ('мужичий', 'соседский', 7, 25),
#  ('тяжкий', 'дудочный', 7, 14),
#  ('пионерский', 'достояние', 8, 32),
#  ('меланхолический', 'меланхоличный', 4, 79),
#  ('охладить', 'зубастый', 7, 25),
#  ('гончарный', 'гончарский', 3, 74),
#  ('зубастый', 'шествовать', 10, 22),
#  ('стеклянный', 'стекольный', 3, 80),
#  ('гуманность', 'хлеборобный', 10, 10),
#  ('ригористичный', 'комитент', 9, 38),
#  ('сочинительский', 'сочинительный', 3, 81),
#  ('обязать', 'оформительский', 11, 29),
#  ('яблочный', 'зрительский', 9, 21),
#  ('овчарня', 'овчарка', 2, 71),
#  ('простудливый', 'простудный', 3, 82),
#  ('двойной', 'швейцарец', 7, 25),
#  ('мифический', 'мифичный', 4, 67),
#  ('подхалимный', 'могущественный', 10, 32),
#  ('могильник', 'комический', 7, 32),
#  ('акционерский', 'досадливо', 11, 29),
#  ('дождевой', 'дождливый', 3, 71),
#  ('опасно', 'опасливо', 3, 71),
#  ('крокодиловый', 'крокодилий', 3, 82),
#  ('заплатить', 'шествовать', 8, 32),
#  ('коллекторный', 'коллекторский', 3, 80),
#  ('гармонический', 'гармоничный', 4, 75),
#  ('юмористический', 'юмористичный', 4, 77),
#  ('мелодика', 'мелодия', 2, 80),
#  ('взбитый', 'сбитый', 2, 77),
#  ('узорчатый', 'узорный', 3, 75),
#  ('дельный', 'докучливый', 6, 47),
#  ('могущественный', 'могучий', 9, 48),
#  ('перегородчатый', 'ритмичный', 10, 35),
#  ('поворотливый', 'восход', 10, 33),
#  ('игристый', 'игривый', 2, 80),
#  ('аллегри', 'зрительский', 9, 22),
#  ('мелодраматический', 'мелодраматичный', 4, 81),
#  ('жестокий', 'истеричный', 7, 44),
#  ('церковнический', 'талан', 13, 11),
#  ('звериный', 'вегетативный', 7, 60),
#  ('обессилеть', 'обессилить', 1, 90),
#  ('летательный', 'летальный', 2, 90),
#  ('временщик', 'дисгармония', 9, 40),
#  ('коллекторский', 'гигиенический', 8, 38),
#  ('царственный', 'личный', 8, 35),
#  ('добротный', 'добрый', 3, 80),
#  ('огородить', 'зачинщик', 8, 12),
#  ('помета', 'гидрат', 6, 17),
#  ('маслянистый', 'масляный', 3, 84),
#  ('ближний', 'близкий', 2, 71),
#  ('венерический', 'венерологический', 4, 86),
#  ('чудный', 'чудной', 1, 83),
#  ('живучий', 'представительный', 14, 26),
#  ('языковой', 'языковый', 1, 88),
#  ('гидрант', 'гидрат', 1, 92),
#  ('обзолотить', 'сладкий', 9, 24),
#  ('скрытый', 'масляный', 6, 40),
#  ('идеалистичный', 'идеалистистический', 7, 71),
#  ('экзерциции', 'молодить', 9, 11),
#  ('языковый', 'языковой', 1, 88),
#  ('экскаватор', 'эскалатор', 2, 84),
#  ('отклик', 'господний', 7, 27),
#  ('вражеский', 'грамматичный', 8, 38),
#  ('вешалка', 'одновременный', 11, 20),
#  ('комичный', 'озлить', 7, 29),
#  ('тяготить', 'тяготеть', 1, 88),
#  ('формат', 'формант', 1, 92),
#  ('настигать', 'слоновий', 9, 24),
#  ('переродиться', 'ванная', 11, 11),
#  ('расточительный', 'тюлений', 10, 38),
#  ('сдвинуть', 'покорный', 8, 12),
#  ('надувательский', 'дерзить', 12, 29),
#  ('стряхнуть', 'понимание', 9, 11),
#  ('ошеек', 'рыболов', 7, 17),
#  ('непроницаемый', 'отчётный', 10, 38),
#  ('автобиографический', 'автобиографичный', 4, 82),
#  ('командировочный', 'командированный', 2, 87),
#  ('скрытный', 'скрытый', 1, 93),
#  ('земляной', 'земной', 2, 86),
#  ('душевность', 'искательский', 11, 27),
#  ('ординарческий', 'ординарный', 5, 70),
#  ('безответный', 'безответственный', 5, 81),
#  ('оппортунистический', 'исходный', 15, 23),
#  ('антагонистичный', 'антагонистический', 4, 81),
#  ('движитель', 'орлёный', 9, 12),
#  ('дедушкин', 'дедовский', 4, 59),
#  ('вассальный', 'вассальский', 3, 76),
#  ('дедушкин', 'заблуждаться', 11, 10),
#  ('подголовок', 'вздох', 8, 27),
#  ('вакханальный', 'подстричь', 11, 10),
#  ('спасительный', 'венец', 10, 24),
#  ('экономия', 'вакхальный', 9, 22),
#  ('дивизия', 'рисковый', 7, 27),
#  ('складской', 'складной', 2, 82),
#  ('юмореска', 'владеть', 7, 13),
#  ('ломить', 'ломать', 1, 83),
#  ('оградить', 'отграничить', 4, 74),
#  ('швейцар', 'швейцарец', 2, 88),
#  ('чиновничий', 'чиновницкий', 2, 86),
#  ('изучить', 'выучить', 2, 71),
#  ('будний', 'будничный', 3, 80),
#  ('антипатический', 'вольный', 13, 19),
#  ('стрелец', 'разный', 7, 15),
#  ('автобиографический', 'гагаровый', 15, 30),
#  ('различие', 'юмористический', 10, 36),
#  ('собирательный', 'ребячливый', 9, 43),
#  ('оформительный', 'борзый', 9, 42),
#  ('охладить', 'крашеный', 8, 12),
#  ('светить', 'светлить', 1, 93),
#  ('шершавить', 'редить', 5, 53),
#  ('изысканный', 'взыскательный', 5, 70),
#  ('обезножеть', 'бунтарь', 7, 47),
#  ('благотворительный', 'благотворный', 5, 83),
#  ('предоставление', 'синить', 12, 30),
#  ('архаичный', 'архаический', 4, 70),
#  ('обсуждение', 'злой', 10, 14),
#  ('купальщик', 'идеалистистический', 14, 30),
#  ('гневливый', 'реабилитированный', 12, 46),
#  ('ребрастый', 'дипломатия', 9, 21),
#  ('вымысел', 'измышление', 7, 35),
#  ('отходный', 'комфортабельный', 10, 43),
#  ('штатский', 'постричь', 7, 25),
#  ('тяжко', 'тягостно', 5, 46),
#  ('темнить', 'темнеть', 1, 86),
#  ('холодеть', 'приметать', 7, 35),
#  ('представить', 'предоставить', 1, 96),
#  ('холопский', 'фантазирование', 12, 17),
#  ('домоправление', 'широтный', 11, 19),
#  ('широкий', 'широтный', 3, 67),
#  ('бунтарь', 'бунтовщик', 5, 50),
#  ('зеленить', 'зеленеть', 1, 88),
#  ('сладостный', 'сладкий', 5, 59),
#  ('черствить', 'выгода', 9, 13),
#  ('безголосый', 'достигать', 10, 21),
#  ('академический', 'декларационный', 11, 37),
#  ('настигать', 'достигать', 2, 78),
#  ('кожный', 'огрызаться', 9, 25),
#  ('обрывчатый', 'обрывочный', 3, 80),
#  ('полнеть', 'полнить', 1, 86),
#  ('близкий', 'ближний', 2, 71),
#  ('существо', 'сущность', 4, 62),
#  ('изыскательный', 'обидчивый', 11, 27),
#  ('накрапывать', 'рогатый', 9, 33),
#  ('аритмичный', 'аритмический', 4, 73),
#  ('гашёный', 'гашенный', 2, 80),
#  ('ненавистнический', 'проблемный', 14, 23),
#  ('отборный', 'отборочный', 2, 89),
#  ('деловитый', 'деловой', 3, 75),
#  ('терпимость', 'одышка', 10, 12),
#  ('деловой', 'бабский', 6, 14),
#  ('жилой', 'выписать', 7, 15),
#  ('новация', 'инновация', 2, 88),
#  ('эфемерный', 'преобразовательный', 13, 37),
#  ('гостиничный', 'гостинный', 2, 90),
#  ('оглупить', 'черепаший', 8, 24),
#  ('дифференцированный', 'варенный', 12, 46),
#  ('житейский', 'жизненный', 6, 44),
#  ('строительный', 'строительский', 3, 80),
#  ('лиричный', 'лирический', 4, 67),
#  ('обезводеть', 'обезводить', 1, 90),
#  ('приютный', 'на дыбы', 7, 27),
#  ('величие', 'величина', 2, 80),
#  ('дедовский', 'дедушкин', 4, 59),
#  ('произнесение', 'мистичный', 10, 29),
#  ('высветить', 'обогреть', 7, 35),
#  ('динамический', 'динамичный', 4, 73),
#  ('изыскательский', 'изыскательный', 3, 81),
#  ('налагать', 'дисквалификация', 12, 26),
#  ('белить', 'белеть', 1, 83),
#  ('кожный', 'кожаный', 1, 92),
#  ('звуковой', 'волнующий', 8, 35),
#  ('абстракция', 'шлифовальник', 10, 18),
#  ('мудрить', 'поэтичный', 8, 12),
#  ('антагонистический', 'антагонистичный', 4, 81),
#  ('душевность', 'духовность', 2, 80),
#  ('мужичий', 'гигиеничный', 8, 33),
#  ('ветряной', 'ветровой', 2, 75),
#  ('солитёр', 'критический', 10, 22),
#  ('помета', 'пометка', 1, 92),
#  ('демократичность', 'демократия', 6, 72),
#  ('бедный', 'бедственный', 5, 71),
#  ('налагать', 'пополнить', 7, 35),
#  ('ненавистнический', 'сочинительный', 12, 34),
#  ('гордость', 'могучий', 7, 13),
#  ('безграмотный', 'неграмотный', 2, 87),
#  ('тягостный', 'тяжкий', 6, 40),
#  ('гадальный', 'депрессия', 9, 11),
#  ('аритмический', 'аритмичный', 4, 73),
#  ('праздничный', 'праздный', 3, 84),
#  ('ювелирный', 'ювелирский', 3, 74),
#  ('гарантированный', 'гарантийный', 5, 77),
#  ('глупить', 'глупеть', 1, 86),
#  ('лакировочный', 'игральный', 8, 48),
#  ('опасный', 'наёмный', 4, 57),
#  ('орлиный', 'шумный', 4, 46),
#  ('добавить', 'заходить', 5, 50),
#  ('истребительский', 'бур', 14, 11),
#  ('интранет', 'интернет', 2, 88),
#  ('искусно', 'безыскусственный', 11, 43),
#  ('коренной', 'проблематичный', 10, 36),
#  ('кардинальский', 'кардинальный', 3, 80),
#  ('прожигательный', 'прожигательский', 3, 83),
#  ('дегенерация', 'регенерация', 1, 91),
#  ('диалектизм', 'диалект', 3, 82),
#  ('дипломатика', 'дипломатия', 2, 86),
#  ('вспрыгнуть', 'лесистый', 10, 22),
#  ('рождать', 'рожать', 1, 92),
#  ('вороний', 'обеднить', 6, 40),
#  ('личностный', 'личный', 4, 75),
#  ('демонтаж', 'гигиеничный', 10, 21),
#  ('поедим', 'элитный', 7, 15),
#  ('восполнить', 'заполнить', 3, 74),
#  ('потоки', 'главный', 7, 0),
#  ('покупательный', 'покупательский', 3, 81),
#  ('работник', 'рабочий', 3, 67),
#  ('признательный', 'подстричь', 11, 36),
#  ('знамение', 'знамя', 4, 62),
#  ('великий', 'цветы', 6, 33),
#  ('в одиночестве', 'наедине', 9, 40),
#  ('длительный', 'длинный', 4, 71),
#  ('учредительный', 'коллекторный', 9, 40),
#  ('блестеть', 'мельничный', 9, 22),
#  ('войти', 'взойти', 1, 91),
#  ('упадочнический', 'упадочный', 6, 70),
#  ('чудной', 'чудный', 1, 83),
#  ('экономика', 'экономия', 2, 82),
#  ('анархичный', 'анархический', 4, 73),
#  ('кожный', 'огреть', 6, 17),
#  ('обидный', 'ограничение', 8, 33),
#  ('отрывок', 'авторитарный', 10, 42),
#  ('эстетический', 'эстетичный', 4, 73),
#  ('фантазирование', 'артистический', 11, 37),
#  ('затруднённый', 'затруднительный', 5, 74),
#  ('продуктивный', 'чиновничий', 10, 36),
#  ('конский', 'оглупеть', 8, 13),
#  ('фабрикат', 'клетчатый', 8, 35),
#  ('однокорневой', 'завидливый', 10, 27),
#  ('уклоняться', 'отклоняться', 2, 86),
#  ('кардинальный', 'кардинальский', 3, 80),
#  ('разночинский', 'ароматичный', 10, 43),
#  ('мудрить', 'мудреть', 1, 86),
#  ('свесить', 'единоверный', 9, 22),
#  ('жавороночный', 'громкий', 9, 32),
#  ('увеселительный', 'весёлый', 8, 57),
#  ('фанатичный', 'фанатический', 4, 73),
#  ('атавистичный', 'атавистический', 4, 77),
#  ('действительный', 'действенный', 4, 80),
#  ('разливчатый', 'прозаический', 8, 43),
#  ('отклоняться', 'уклоняться', 2, 86),
#  ('вороний', 'вороновый', 3, 75),
#  ('поворотливый', 'цепенеть', 11, 20),
#  ('бунтовщик', 'бородатый', 8, 22),
#  ('различный', 'разный', 3, 80),
#  ('пророческий', 'пророчественный', 6, 69),
#  ('несоизмеримый', 'непонятный', 8, 43),
#  ('неврастенический', 'неврастеничный', 4, 80),
#  ('сопротивляемость', 'сопротивление', 6, 69),
#  ('седельный', 'выписать', 9, 24),
#  ('декорационный', 'человеческий', 10, 32),
#  ('связываться', 'вязаться', 3, 84),
#  ('раскольничий', 'производственный', 13, 29),
#  ('иронический', 'ироничный', 4, 70),
#  ('двойной', 'двоичный', 3, 67),
#  ('экономичный', 'экономический', 4, 75),
#  ('обезлюдить', 'обезлюдеть', 1, 90),
#  ('знамя', 'знамение', 4, 62),
#  ('проблемный', 'проблематичный', 4, 83),
#  ('мелкотравчатый', 'накрапливать', 11, 46),
#  ('ароматичный', 'покупательский', 11, 40),
#  ('подбородок', 'чудный', 9, 12),
#  ('пугливый', 'ненавистный', 8, 32),
#  ('поэтический', 'затруднительный', 12, 31),
#  ('протрезветь', 'холодильник', 11, 18),
#  ('бесчувствие', 'бесчувственность', 7, 74),
#  ('зловещий', 'рыбный', 7, 14),
#  ('статичный', 'негласный', 6, 44),
#  ('держать', 'покорный', 8, 13),
#  ('чудной', 'трагический', 9, 24),
#  ('чубастый', 'чубатый', 1, 93),
#  ('типичный', 'типический', 4, 67),
#  ('производственный', 'производный', 5, 81),
#  ('безгласный', 'негласный', 2, 84),
#  ('блистать', 'блестеть', 2, 75),
#  ('наследный', 'вассальный', 5, 63),
#  ('блудить', 'блуждать', 2, 80),
#  ('керосиновый', 'дипломант', 10, 20),
#  ('переливочный', 'переливчатый', 3, 83),
#  ('ответный', 'бесчувственность', 12, 33),
#  ('экологический', 'экологичный', 4, 75),
#  ('двойняшки', 'динамизм', 8, 35),
#  ('ароматический', 'ароматичный', 4, 75),
#  ('представительский', 'представительный', 3, 85),
#  ('сиеста', 'редить', 5, 33),
#  ('владеть', 'поверка', 7, 29),
#  ('статичный', 'настоятельный', 7, 55),
#  ('венерологический', 'венерический', 4, 86),
#  ('невиновный', 'ненавистнический', 10, 46),
#  ('аккордовый', 'вздрогнуть', 10, 20),
#  ('человеческий', 'допуск', 9, 33),
#  ('памятный', 'осветитель', 9, 11),
#  ('раковый', 'рачий', 4, 50),
#  ('декларативный', 'декларационный', 3, 81),
#  ('интеллигентский', 'интеллигентный', 3, 83),
#  ('безыскусный', 'безыскусственный', 5, 81),
#  ('бур', 'зимовщик', 8, 0),
#  ('хищнический', 'хищный', 6, 59),
#  ('доверие', 'обесплодить', 9, 33),
#  ('содержать', 'раскольничий', 10, 29),
#  ('затруднённый', 'глубокий', 10, 20),
#  ('российский', 'русский', 4, 71),
#  ('раскрытие', 'гарантийный', 9, 40),
#  ('автономия', 'автономность', 5, 67),
#  ('червить', 'червиветь', 2, 88),
#  ('вырастить', 'нарастить', 2, 78),
#  ('расточительский', 'благоустройство', 12, 33),
#  ('информация', 'информированность', 10, 52),
#  ('волнующий', 'фабрикант', 9, 11),
#  ('перегородочный', 'одеть', 12, 21),
#  ('формат', 'гордый', 4, 33),
#  ('пакостливый', 'пакостный', 3, 80),
#  ('ответственный', 'ответный', 5, 76),
#  ('преемник', 'несоизмеримый', 11, 29),
#  ('вешалка', 'действенный', 10, 22),
#  ('штурмовщик', 'штурмовик', 1, 95),
#  ('побуждать', 'возбуждать', 2, 84),
#  ('взбежать', 'старательский', 11, 29),
#  ('индийский', 'индейский', 1, 89),
#  ('масленый', 'ароматический', 9, 38),
#  ('червы', 'черви', 1, 80),
#  ('варение', 'вымысел', 6, 29),
#  ('заблудиться', 'снискать', 9, 32),
#  ('демонстративный', 'крючкотворный', 11, 43),
#  ('удвоенный', 'сдвоенный', 1, 89),
#  ('особенный', 'беженец', 7, 38),
#  ('лирник', 'лирик', 1, 91),
#  ('изначально', 'искусно', 7, 35),
#  ('шумный', 'шумовой', 3, 62),
#  ('дипломатический', 'бородастый', 11, 32),
#  ('законодательный', 'основание', 11, 42),
#  ('переродиться', 'переродниться', 1, 96),
#  ('запасный', 'запасливый', 3, 78),
#  ('производительность', 'производство', 8, 67),
#  ('холодить', 'холодеть', 1, 88),
#  ('цикличный', 'обезводить', 10, 11),
#  ('досадливо', 'досадно', 3, 75),
#  ('беззаконность', 'беззаконие', 5, 70),
#  ('Антарктика', 'Арктика', 3, 82),
#  ('съёмочный', 'съёмный', 2, 88),
#  ('кожный', 'аргонавт', 7, 29),
#  ('эфемерный', 'женственный', 7, 50),
#  ('англиканский', 'эфемерный', 10, 19),
#  ('политичный', 'каменистый', 7, 40),
#  ('декорационный', 'декоративный', 3, 80),
#  ('покорливый', 'игривый', 5, 59),
#  ('проповедничий', 'экспонат', 10, 29),
#  ('дарёный', 'обоснование', 10, 22),
#  ('отчётливый', 'отчётный', 3, 78),
#  ('деспотизм', 'подделка', 9, 24),
#  ('репрессия', 'подстричь', 8, 33),
#  ('юмористический', 'заглавный', 13, 9),
#  ('деспотичный', 'деспотический', 4, 75),
#  ('взвалить', 'абстракция', 9, 22),
#  ('исток', 'источник', 3, 77),
#  ('распутница', 'распутица', 1, 95),
#  ('освоить', 'усвоить', 1, 86),
#  ('учредительский', 'учредительный', 3, 81),
#  ('явственно', 'покорный', 8, 12),
#  ('охотливо', 'подделка', 7, 25),
#  ('спускной', 'рисковый', 6, 50),
#  ('освоить', 'академический', 12, 20),
#  ('антипедагогический', 'надеть', 15, 25),
#  ('симптоматичный', 'строительный', 9, 54),
#  ('патриотичный', 'венец', 11, 12),
#  ('червиветь', 'червить', 2, 88),
#  ('мастистый', 'представить', 9, 40),
#  ('российский', 'хлеборобский', 8, 55),
#  ('благоустроенность', 'благоустройство', 6, 75),
#  ('дерзить', 'обессилить', 6, 47),
#  ('конский', 'конный', 3, 62),
#  ('автоматический', 'произнесение', 11, 38),
#  ('дипломатия', 'изверуский', 9, 20),
#  ('аристократичный', 'аристократический', 4, 81),
#  ('геройский', 'героический', 3, 80),
#  ('ветровой', 'яблоневый', 7, 35),
#  ('безыскусный', 'густить', 10, 22),
#  ('активировать', 'бобёр', 11, 12),
#  ('сбитый', 'взбитый', 2, 77),
#  ('тряхнуть', 'схоластичный', 11, 20),
#  ('в общем', 'варкий', 6, 15),
#  ('циклический', 'собирательский', 9, 48),
#  ('действенный', 'действительный', 4, 80),
#  ('обесплодить', 'величественный', 12, 32),
#  ('воинский', 'военный', 4, 53),
#  ('городничий', 'городовой', 4, 63),
#  ('покорливый', 'дидактичный', 8, 38),
#  ('вариант', 'яловый', 7, 15),
#  ('удвоенный', 'садовнический', 9, 36),
#  ('дифференцированный', 'дифференциальный', 5, 82),
#  ('мелодраматичный', 'мелодраматический', 4, 81),
#  ('вакханальный', 'вакхальный', 2, 91),
#  ('синеть', 'деляческий', 9, 25),
#  ('жилищный', 'жилой', 4, 62),
#  ('бывалый', 'бывший', 3, 62),
#  ('фантазёрство', 'фантазирование', 7, 62),
#  ('поверка', 'проверка', 1, 93),
#  ('невежа', 'благодарственный', 14, 18),
#  ('отклонение', 'уклонение', 2, 84),
#  ('домоправление', 'домоуправление', 1, 96),
#  ('красочный', 'поспешливый', 9, 30),
#  ('купальник', 'прожигательный', 10, 43),
#  ('летательный', 'дефектный', 6, 50),
#  ('ритмический', 'ритмичный', 4, 70),
#  ('просёлок', 'посёлок', 1, 93),
#  ('крючкотворский', 'крючкотворный', 3, 81),
#  ('факт', 'декларационный', 13, 11),
#  ('сдвоенный', 'удвоенный', 1, 89),
#  ('симптоматичный', 'аристократичный', 6, 69),
#  ('спасательный', 'спасительный', 1, 92),
#  ('декларационный', 'декларативный', 3, 81),
#  ('системный', 'систематический', 8, 58),
#  ('экранировать', 'антагонистический', 14, 28),
#  ('осуждение', 'обсуждение', 1, 95),
#  ('живительный', 'живучий', 7, 56),
#  ('оживлять', 'напоминание', 9, 21),
#  ('спусковой', 'спускной', 2, 82),
#  ('разодеть', 'раздеть', 1, 93),
#  ('оболванеть', 'оболванить', 1, 90),
#  ('адресант', 'адресат', 1, 93),
#  ('произвольный', 'вольный', 5, 74),
#  ('густить', 'отчётливый', 8, 24),
#  ('отборщик', 'отборник', 1, 88),
#  ('раскрытие', 'вскрытие', 2, 82),
#  ('затруднительный', 'двойственный', 11, 44),
#  ('лиричный', 'узорный', 5, 53),
#  ('волнующий', 'волнительный', 7, 57),
#  ('фланелевый', 'порвать', 10, 12),
#  ('соседский', 'соседний', 2, 82),
#  ('разночинский', 'иноверный', 9, 38),
#  ('наблюдательский', 'азартность', 12, 32),
#  ('маститый', 'архаический', 9, 42),
#  ('произнесение', 'прервать', 9, 30),
#  ('полемический', 'авторитарный', 10, 25),
#  ('токсический', 'элитный', 9, 22),
#  ('конъектура', 'феерический', 11, 19),
#  ('антипатичный', 'хватский', 9, 40),
#  ('кокетка', 'веселеть', 7, 27),
#  ('ковочный', 'ковкий', 4, 57),
#  ('органичный', 'различать', 7, 42),
#  ('беззаконность', 'съёмный', 12, 10),
#  ('бородастый', 'пластический', 10, 36),
#  ('дарёный', 'антипедагогичный', 11, 43),
#  ('правительский', 'правительственный', 6, 73),
#  ('опечатать', 'отпечатать', 1, 95),
#  ('жалостливый', 'жалостный', 3, 80),
#  ('человечный', 'демобилизировать', 14, 31),
#  ('просветительский', 'просветительный', 3, 84),
#  ('формант', 'избирательный', 11, 30),
#  ('угодливый', 'угодный', 3, 75),
#  ('поручительный', 'эфирный', 9, 40),
#  ('рисунчатый', 'языковой', 9, 22),
#  ('пакостливый', 'подживать', 8, 40),
#  ('чувственный', 'чувствительный', 4, 80),
#  ('комичный', 'комический', 4, 67),
#  ('советчик', 'советник', 1, 88),
#  ('нетерпимо', 'нестерпимо', 1, 95),
#  ('отрывок', 'гневливый', 8, 12),
#  ('бобёр', 'отирать', 6, 33),
#  ('заводской', 'угодливый', 7, 33),
#  ('головешки', 'грубеть', 7, 25),
#  ('подбор', 'выбор', 3, 55),
#  ('обрывочный', 'рыболов', 7, 35),
#  ('гагарий', 'варение', 5, 43),
#  ('дармоедский', 'дармоедный', 3, 76),
#  ('телевизионщик', 'хозяйский', 11, 18),
#  ('яблочный', 'яблоневый', 3, 82),
#  ('жабный', 'жабий', 2, 73),
#  ('чеканный', 'чеканочный', 2, 89),
#  ('сметливый', 'воедино', 7, 25),
#  ('цинический', 'астронавт', 10, 11),
#  ('снискать', 'оформительский', 12, 27),
#  ('дерзать', 'дерзить', 1, 86),
#  ('заодно', 'восполнить', 8, 25),
#  ('цепенеть', 'цепенить', 1, 88),
#  ('досадный', 'досадливый', 3, 78),
#  ('глиняный', 'единственный', 7, 50),
#  ('обезлошадить', 'изобретательный', 12, 44),
#  ('аристократический', 'аристократичный', 4, 81),
#  ('заразительный', 'заразный', 5, 76),
#  ('дипломатический', 'обезножить', 14, 24),
#  ('солярный', 'садовничий', 7, 44),
#  ('овчарка', 'могильник', 8, 25),
#  ('цвета', 'цветы', 1, 80),
#  ('варенье', 'осветитель', 8, 35),
#  ('посёлок', 'просёлок', 1, 93),
#  ('антипедагогический', 'порумянить', 16, 21),
#  ('конфузливо', 'цепенить', 9, 22),
#  ('обессилить', 'обессилеть', 1, 90),
#  ('пуганый', 'пугливый', 3, 67),
#  ('окаменеть', 'пуганый', 8, 25),
#  ('инородный', 'отборщик', 8, 24),
#  ('оппортунистичный', 'притязательный', 11, 47),
#  ('возмущённый', 'возмутительный', 6, 64),
#  ('сборчатый', 'сборочный', 3, 78),
#  ('вздохнуть', 'зло', 7, 33),
#  ...]
